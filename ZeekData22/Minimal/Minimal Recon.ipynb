# %%
# PySpark Imports
import pyspark
from pyspark.sql import SparkSession

# ML Classifier Imports
from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import mean, col
import time
import os
import sys

# %%
# Initialize Spark session
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.memory", "14g") \
    .config("spark.executor.memory", "14g") \
    .config("spark.executor.cores", "2") \
    .config("spark.dynamicAllocation.shuffleTracking.enabled", "true") \
    .config("spark.dynamicAllocation.enabled", "true") \
    .config("spark.dynamicAllocation.minExecutors", "2") \
    .config("spark.dynamicAllocation.maxExecutors", "2") \
    .config("spark.executor.instances", "2") \
    .config("spark.kryoserializer.buffer.max", "2047m") \
    .config("spark.sql.execution.pythonUDF.arrow.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/04/09 10:20:45 WARN Utils: Your hostname, colin-MS-7977 resolves to a loopback address: 127.0.1.1; using 192.168.0.164 instead (on interface wlx3c52a1d3ccda)
# 24/04/09 10:20:45 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/09 10:20:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/04/09 10:20:46 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
parquet_files = ["Parquet/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet", "Parquet/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet", 
                 "Parquet/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet", "Parquet/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "Parquet/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet", "Parquet/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "Parquet/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet", "Parquet/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet"]

# %%
# Read the parquet files into a dataframe
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
# Get unique labels and their counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the results
label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
start_time = time.time()

# List of labels to drop
labels_to_drop = ["Defense Evasion", "Exfiltration", "Initial Access", "Lateral Movement", "Persistence", "Privilege Escalation", "Resource Development", "Credential Access", "Discovery"]

# Filter out the rows with labels to drop
df = df.filter(~col("label_tactic").isin(labels_to_drop))

# Get unique labels and their counts after filtering
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the filtered results
filtered_label_counts.show()


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# [Stage 4:===================================================>       (7 + 1) / 8]
# +--------------+-------+
# |  label_tactic|  count|
# +--------------+-------+
# |Reconnaissance|9278722|
# |          none|9281599|
# +--------------+-------+
#
# Execution time: 1.7541637420654297 seconds

# %%
start_time = time.time()



df = df.withColumn("datetime", col("datetime").cast("string"))

# Define columns to index
columns_to_index = ['service', 'conn_state', 'history', 'proto', 'dest_ip_zeek', 'community_id', 'uid', 'src_ip_zeek', 'label_tactic', 'datetime']

# Impute null values with 'null' string
for column in columns_to_index:
    df = df.fillna('null', subset=[column])

# Apply StringIndexer to each column
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").fit(df) for column in columns_to_index]

# Chain indexers together
pipeline = Pipeline(stages=indexers)

# Fit and transform the data
df_indexed = pipeline.fit(df).transform(df)

# Drop original columns
df_indexed = df_indexed.drop(*columns_to_index)

# Show the schema of the DataFrame
#df_indexed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 65.23057794570923 seconds

# %%
# Split the data into training and test sets
start_time = time.time()

train_data, test_data = df_indexed.randomSplit([0.7, 0.3], seed=42)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.021151304244995117 seconds

# %%
from pyspark.ml.feature import Imputer


start_time = time.time()

# List of numeric column names
numeric_columns = ['resp_pkts', 'orig_ip_bytes', 'missed_bytes', 'duration', 'orig_pkts',
                   'resp_ip_bytes', 'dest_port_zeek', 'orig_bytes', 'resp_bytes',
                   'src_port_zeek', 'ts']


# Create an Imputer object
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

# Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data)

# Apply the imputer to the training data
train_data_imputed = imputer_model.transform(train_data)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()


# Apply the imputer to the test data
test_data_imputed = imputer_model.transform(test_data)

# Show updated DataFrames
#train_data_imputed.show()
#test_data_imputed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/09 10:22:11 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# [Stage 37:==================================================>       (7 + 1) / 8]
# Execution time: 59.29074954986572 seconds
# Execution time: 0.026200056076049805 seconds

# %%
from pyspark.ml.feature import VectorAssembler


start_time = time.time()



# List of columns to assemble
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed")]

# Create the VectorAssembler
assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

# Transform the training DataFrame
train_data_assembled = assembler.transform(train_data_imputed)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
# Transform the test DataFrame
test_data_assembled = assembler.transform(test_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Select only the features and label columns for both training and test sets
train_data_assembled = train_data_assembled.select("features", "label_tactic_indexed")
test_data_assembled = test_data_assembled.select("features", "label_tactic_indexed")

# Show the schema of the assembled training DataFrame
#train_data_assembled.printSchema()

# Show the schema of the assembled test DataFrame
#test_data_assembled.printSchema()
# Out:
# Execution time: 5.556607723236084 seconds
# Execution time: 0.07311201095581055 seconds

# %%
# Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic_indexed", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)

# One Vs. Rest
ovr = OneVsRest(classifier=svm, labelCol='label_tactic_indexed')

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Fit the model
start_time = time.time()

svm_model = ovr.fit(train_data_assembled)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.027055978775024414 seconds
# 24/04/09 10:23:17 WARN DAGScheduler: Broadcasting large task binary with size 268.2 MiB
# 24/04/09 10:24:13 WARN DAGScheduler: Broadcasting large task binary with size 268.2 MiB
# 24/04/09 10:25:20 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:25:43 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:25:48 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/04/09 10:26:00 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:26:27 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:26:42 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:27:00 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:27:17 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:27:34 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:27:51 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:28:08 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:28:26 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:28:43 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:28:59 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:29:16 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:29:35 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:29:51 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:30:06 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:30:27 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:30:42 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:31:01 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:31:19 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:31:36 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:31:51 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:32:11 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:32:29 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:32:46 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:33:02 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:33:19 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:33:35 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:33:52 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:34:07 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:34:27 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:34:43 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:35:00 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:35:15 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:35:35 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:35:52 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:36:08 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:36:26 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:36:43 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:37:00 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:37:17 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:37:34 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:37:51 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:38:08 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:38:25 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:38:42 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:38:59 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:39:14 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:39:34 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:39:49 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:40:08 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:40:24 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:40:47 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:41:02 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:41:29 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:41:44 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:42:03 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:42:18 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:42:35 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:42:54 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:43:11 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:43:27 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:43:46 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:44:01 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:44:18 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:44:34 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:44:51 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:45:06 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:45:25 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:45:43 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:46:01 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:46:17 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:46:33 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:46:50 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:47:06 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:47:21 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:47:40 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:47:55 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:48:13 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:48:29 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:48:46 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:49:01 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:49:18 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:49:34 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:49:53 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:50:08 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:50:29 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:50:46 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:51:03 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:51:21 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:51:38 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:51:55 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:52:12 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:52:28 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:52:45 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:53:01 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:53:20 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:53:37 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:53:55 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:54:11 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:54:28 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:54:46 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 10:55:02 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# Execution time: 1922.5706224441528 seconds

# %%
# Make predictions
start_time = time.time()

predictions = svm_model.transform(test_data_assembled)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.3296542167663574 seconds

# %%
# Evaluate the model
# Calculate accuracy
start_time = time.time()
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)
print("Accuracy:", accuracy)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate precision
start_time = time.time()
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)
print("Precision:", precision)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate recall
start_time = time.time()
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)
print("Recall:", recall)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate F1-score
start_time = time.time()
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)
print("F1-Score:", f1_score)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
# Out:
# 24/04/09 10:55:37 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# Accuracy: 0.9996810384354073
# Execution time: 150.1495099067688 seconds
# 24/04/09 10:58:05 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# Precision: 0.9996812419070147
# Execution time: 147.38651752471924 seconds
# 24/04/09 11:00:32 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# Recall: 0.9996810384354073
# Execution time: 145.97305464744568 seconds
# 24/04/09 11:02:58 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# [Stage 157:=================================================>       (7 + 1) / 8]
# F1-Score: 0.9996810384671814
# Execution time: 144.74505972862244 seconds
# Accuracy: 0.9996810384354073
# Precision: 0.9996812419070147
# Recall: 0.9996810384354073
# F1-Score: 0.9996810384671814

# %%
from pyspark.sql.functions import expr

start_time = time.time()

# Extract Predictions and True Labels
predictions_and_labels = predictions.select("prediction", "label_tactic_indexed")

# Calculate False Positives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate True Negatives
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate False Positive Rate (FPR)
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/09 11:05:23 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/09 11:06:59 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# [Stage 162:=================================================>       (7 + 1) / 8]
# False Positive Rate: 0.0006375206763462598
# Execution time: 193.50154900550842 seconds

# %%
spark.sparkContext.stop()
