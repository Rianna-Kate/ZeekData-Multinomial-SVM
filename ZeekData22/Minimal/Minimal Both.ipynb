# %%
# PySpark Imports
import pyspark
from pyspark.sql import SparkSession

# ML Classifier Imports
from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import mean, col
import time
import os
import sys

# %%
# Initialize Spark session
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.memory", "14g") \
    .config("spark.executor.memory", "14g") \
    .config("spark.executor.cores", "2") \
    .config("spark.dynamicAllocation.shuffleTracking.enabled", "true") \
    .config("spark.dynamicAllocation.enabled", "true") \
    .config("spark.dynamicAllocation.minExecutors", "2") \
    .config("spark.dynamicAllocation.maxExecutors", "2") \
    .config("spark.executor.instances", "2") \
    .config("spark.kryoserializer.buffer.max", "2047m") \
    .config("spark.sql.execution.pythonUDF.arrow.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/04/29 00:12:50 WARN Utils: Your hostname, colin-MS-7977 resolves to a loopback address: 127.0.1.1; using 192.168.0.164 instead (on interface wlx3c52a1d3ccda)
# 24/04/29 00:12:50 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/29 00:12:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
parquet_files = ["Parquet/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet", "Parquet/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet", 
                 "Parquet/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet", "Parquet/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "Parquet/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet", "Parquet/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "Parquet/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet", "Parquet/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet"]

# %%
# Read the parquet files into a dataframe
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
# Get unique labels and their counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the results
label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
start_time = time.time()

# List of labels to drop
labels_to_drop = ["Defense Evasion", "Exfiltration", "Initial Access", "Lateral Movement", "Persistence", "Privilege Escalation", "Resource Development", "Credential Access"]

# Filter out the rows with labels to drop
df = df.filter(~col("label_tactic").isin(labels_to_drop))

# Get unique labels and their counts after filtering
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the filtered results
filtered_label_counts.show()


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# [Stage 4:===================================================>       (7 + 1) / 8]
# +--------------+-------+
# |  label_tactic|  count|
# +--------------+-------+
# |     Discovery|   2086|
# |Reconnaissance|9278722|
# |          none|9281599|
# +--------------+-------+
#
# Execution time: 1.6518011093139648 seconds

# %%
start_time = time.time()



df = df.withColumn("datetime", col("datetime").cast("string"))

# Define columns to index
columns_to_index = ['service', 'conn_state', 'history', 'proto', 'dest_ip_zeek', 'community_id', 'uid', 'src_ip_zeek', 'label_tactic', 'datetime']

# Impute null values with 'null' string
for column in columns_to_index:
    df = df.fillna('null', subset=[column])

# Apply StringIndexer to each column
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").fit(df) for column in columns_to_index]

# Chain indexers together
pipeline = Pipeline(stages=indexers)

# Fit and transform the data
df_indexed = pipeline.fit(df).transform(df)

# Drop original columns
df_indexed = df_indexed.drop(*columns_to_index)

# Show the schema of the DataFrame
#df_indexed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 70.72318148612976 seconds

# %%
# Split the data into training and test sets
start_time = time.time()

train_data, test_data = df_indexed.randomSplit([0.7, 0.3], seed=42)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.02353811264038086 seconds

# %%
from pyspark.ml.feature import Imputer


start_time = time.time()

# List of numeric column names
numeric_columns = ['resp_pkts', 'orig_ip_bytes', 'missed_bytes', 'duration', 'orig_pkts',
                   'resp_ip_bytes', 'dest_port_zeek', 'orig_bytes', 'resp_bytes',
                   'src_port_zeek', 'ts']


# Create an Imputer object
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

# Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data)

# Apply the imputer to the training data
train_data_imputed = imputer_model.transform(train_data)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()


# Apply the imputer to the test data
test_data_imputed = imputer_model.transform(test_data)

# Show updated DataFrames
#train_data_imputed.show()
#test_data_imputed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/29 00:14:23 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# Execution time: 70.48609161376953 seconds
# Execution time: 0.028431415557861328 seconds

# %%
from pyspark.ml.feature import VectorAssembler


start_time = time.time()



# List of columns to assemble
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed")]

# Create the VectorAssembler
assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

# Transform the training DataFrame
train_data_assembled = assembler.transform(train_data_imputed)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
# Transform the test DataFrame
test_data_assembled = assembler.transform(test_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Select only the features and label columns for both training and test sets
train_data_assembled = train_data_assembled.select("features", "label_tactic_indexed")
test_data_assembled = test_data_assembled.select("features", "label_tactic_indexed")

# Show the schema of the assembled training DataFrame
#train_data_assembled.printSchema()

# Show the schema of the assembled test DataFrame
#test_data_assembled.printSchema()
# Out:
# Execution time: 4.452489852905273 seconds
# Execution time: 0.09295439720153809 seconds

# %%
# Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic_indexed", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)

# One Vs. Rest
ovr = OneVsRest(classifier=svm, labelCol='label_tactic_indexed')

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Fit the model
start_time = time.time()

svm_model = ovr.fit(train_data_assembled)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.02863311767578125 seconds
# 24/04/29 00:15:38 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# 24/04/29 00:16:49 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:18:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:18:39 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:18:45 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/04/29 00:18:58 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:19:36 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:19:55 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:20:15 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:20:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:21:00 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:21:20 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:21:42 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:22:03 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:22:22 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:22:42 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:23:05 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:23:25 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:23:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:24:05 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:24:27 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:24:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:25:09 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:25:32 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:25:52 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:26:13 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:26:34 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:26:58 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:27:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:27:42 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:28:04 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:28:20 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:28:41 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:28:57 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:29:15 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:29:32 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:29:49 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:30:06 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:30:26 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:30:42 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:31:02 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:31:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:31:39 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:31:58 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:32:15 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:32:31 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:32:51 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:33:07 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:33:25 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:33:42 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:34:01 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:34:18 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:34:36 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:34:54 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:35:12 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:35:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:35:53 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:36:10 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:36:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:36:54 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:37:12 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:37:29 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:37:47 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:38:05 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:38:23 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:38:40 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:39:00 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:39:15 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:39:34 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:39:51 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:40:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:40:24 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:40:45 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:41:03 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:41:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:41:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:41:56 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:42:13 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:42:31 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:42:49 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:43:09 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:43:25 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:43:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:44:03 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:44:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:44:37 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:44:57 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:45:15 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:45:32 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:45:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:46:10 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:46:32 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:46:51 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:47:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:47:26 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:47:44 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:48:02 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:48:20 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:48:37 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:48:55 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:49:13 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:49:29 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:49:50 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:50:07 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:50:25 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:50:43 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:51:01 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:51:19 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:51:44 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:52:02 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:52:29 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:52:45 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:53:04 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:53:22 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:53:40 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:53:58 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:54:16 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:54:34 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:54:52 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:55:10 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:55:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:55:45 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:56:03 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:56:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:56:39 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:57:00 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:57:20 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:57:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:57:55 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:58:13 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:58:31 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:58:47 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:59:10 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:59:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 00:59:53 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:00:09 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:00:30 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:00:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:01:06 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:01:24 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:01:41 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:01:59 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:02:17 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:02:34 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:02:52 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:03:09 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:03:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:03:47 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:04:05 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:04:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:04:41 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:04:57 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:05:15 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:05:33 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:05:51 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:06:09 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:06:31 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:07:00 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:07:29 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:07:49 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:08:09 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:08:29 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:08:49 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:09:05 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:09:24 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:09:43 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:10:01 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:10:18 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:10:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:11:00 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:11:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:11:41 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:12:02 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:12:22 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:12:44 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:13:05 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:13:25 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:13:45 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:14:06 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:14:26 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:14:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:15:06 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:15:26 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:15:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:16:06 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:16:27 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:16:47 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:17:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:17:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:17:47 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:18:07 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:18:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:18:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:19:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:19:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:19:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:20:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:20:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:20:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:21:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:21:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:21:49 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:22:10 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:22:30 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:22:50 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:23:07 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:23:25 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:23:43 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:24:01 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:24:20 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:24:39 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:24:57 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:25:17 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:25:36 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:25:54 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# Execution time: 4234.196822166443 seconds

# %%
# Make predictions
start_time = time.time()

predictions = svm_model.transform(test_data_assembled)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.4436485767364502 seconds

# %%
# Evaluate the model
# Calculate accuracy
start_time = time.time()
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)
print("Accuracy:", accuracy)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate precision
start_time = time.time()
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)
print("Precision:", precision)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate recall
start_time = time.time()
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)
print("Recall:", recall)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate F1-score
start_time = time.time()
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)
print("F1-Score:", f1_score)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
# Out:
# 24/04/29 01:26:35 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# Accuracy: 0.9998584951570506
# Execution time: 187.48284149169922 seconds
# 24/04/29 01:29:43 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# Precision: 0.999749174245564
# Execution time: 185.09015822410583 seconds
# 24/04/29 01:32:47 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# Recall: 0.9998584951570506
# Execution time: 181.429292678833 seconds
# 24/04/29 01:35:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# [Stage 265:=================================================>       (7 + 1) / 8]
# F1-Score: 0.9998038241701416
# Execution time: 178.43718910217285 seconds
# Accuracy: 0.9998584951570506
# Precision: 0.999749174245564
# Recall: 0.9998584951570506
# F1-Score: 0.9998038241701416

# %%
from pyspark.sql.functions import expr

start_time = time.time()

# Extract Predictions and True Labels
predictions_and_labels = predictions.select("prediction", "label_tactic_indexed")

# Calculate False Positives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate True Negatives
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate False Positive Rate (FPR)
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/29 01:38:47 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/29 01:40:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# [Stage 270:=================================================>       (7 + 1) / 8]
# False Positive Rate: 6.425535580954569e-05
# Execution time: 237.5567660331726 seconds

# %%
spark.sparkContext.stop()
