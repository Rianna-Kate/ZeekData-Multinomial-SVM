# %%
import pyspark
from pyspark.sql import SparkSession

from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA, Imputer
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.sql.functions import mean, col, expr
import numpy as np
import time

# %%
spark = SparkSession.builder.appName("rka7 - Min. Discovery") \
    .config("SPARK_LOCAL_IP", "192.168.1.2") \
    .master("spark://192.168.1.2:7077") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.maxResultSize", "3g") \
    .config("spark.driver.memory", "10g") \
    .config("spark.executor.memory", "25g") \
    .config("spark.executor.cores", "2") \
    .config("spark.executor.instances", "16") \
    .config("spark.shuffle.partitions", "180") \
    .config("spark.kryoserializer.buffer.max", "256m") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# Warning: Ignoring non-Spark config property: SPARK_LOCAL_IP
# 24/06/26 15:28:27 WARN Utils: Your hostname, ubuntu-virtual-machine resolves to a loopback address: 127.0.1.1; using 192.168.1.107 instead (on interface ens33)
# 24/06/26 15:28:27 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/06/26 15:28:28 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#spark.sparkContext.stop()

# %%
parquet_files = ["hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2021-12-12 - 2021-12-19/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2021-12-19 - 2021-12-26/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2021-12-26 - 2022-01-02/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-01-02 - 2022-01-09/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-01-09 - 2022-01-16/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-01-16 - 2022-01-23/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-02-06 - 2022-02-13/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-02-13 - 2022-02-20/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet"]

# %%
#Read the parquet files
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
#Get unique label counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
start_time = time.time()

#Drop labels and get remaining counts
labels_to_drop = ['Defense Evasion', 
                  'Exfiltration',
                  'Initial Access',
                  'Lateral Movement', 
                  'Persistence',
                  'Privilege Escalation', 
                  'Resource Development', 
                  'Credential Access']
                  #'Discovery',
                  #'Reconnaissance']

df = df.filter(~col("label_tactic").isin(labels_to_drop))

#Get unique label counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")
label_counts.show()
total_count = df.count()
print("Original Total Count:", total_count)

df_none = df.filter(col("label_tactic") != "Discovery")
df = df.filter(col("label_tactic") == "Discovery")
label_counts = df_none.groupBy("label_tactic").count().orderBy("label_tactic")
label_counts.show()

# Reducing 'label_tactic' - "none" & "Reconnaissance" by 95%
df_none = df_none.sample(False, 0.05, seed=42)

label_counts = df_none.groupBy("label_tactic").count().orderBy("label_tactic")
label_counts.show()

label_counts = df.groupBy("label_tactic").count().collect()

# Calculate sampling fractions/proportions for each stratum/category (Doing Stratified Sampling
fractions = {row['label_tactic']: row['count'] / total_count for row in label_counts}

print(fractions)

df = df.filter(col("label_tactic") != "none")
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")
label_counts.show()

df = df_none.union(df)
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")
label_counts.show()

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# +--------------+-------+
# |  label_tactic|  count|
# +--------------+-------+
# |     Discovery|   2086|
# |Reconnaissance|9278722|
# |          none|9281599|
# +--------------+-------+
# Original Total Count: 18562407
# +--------------+-------+
# |  label_tactic|  count|
# +--------------+-------+
# |Reconnaissance|9278722|
# |          none|9281599|
# +--------------+-------+
# +--------------+------+
# |  label_tactic| count|
# +--------------+------+
# |Reconnaissance|464405|
# |          none|463081|
# +--------------+------+
#
# {'Discovery': 0.00011237766740056934}
# +------------+-----+
# |label_tactic|count|
# +------------+-----+
# |   Discovery| 2086|
# +------------+-----+
# [Stage 22:====================================================> (115 + 3) / 118]
# +--------------+------+
# |  label_tactic| count|
# +--------------+------+
# |     Discovery|  2086|
# |Reconnaissance|464405|
# |          none|463081|
# +--------------+------+
#
# Execution time: 10.296845436096191 seconds

# %%
#Drop uid feature
df = df.drop('uid')

# %%
start_time = time.time()

#Columns to index
columns_to_index = ['service', 
                    'conn_state', 
                    'history', 
                    'proto', 
                    'dest_ip_zeek', 
                    'community_id', 
                    'src_ip_zeek',
                    'datetime',
                    'local_resp',
                    'local_orig',
                    'label_tactic']

#Cast datetime, local_resp, local_orig to String
df = df.withColumn("datetime", col("datetime").cast("string"))
df = df.withColumn("local_resp", col("local_resp").cast("string"))
df = df.withColumn("local_orig", col("local_orig").cast("string"))

#Impute null values with empty string
for column in columns_to_index:
    df = df.fillna('', subset=[column])

# %%
#Split the into training and test sets
start_time = time.time()
train_data, test_data = df.randomSplit([0.7, 0.3], seed=42)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.02706456184387207 seconds

# %%
#StringIndexer
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").setHandleInvalid("keep") for column in columns_to_index]

#Chain indexers together
pipeline = Pipeline(stages=indexers).fit(train_data)

#Fit and transform the data
train_data_indexed = pipeline.transform(train_data)
test_data_indexed = pipeline.transform(test_data)

#Drop original columns
train_data_indexed = train_data_indexed.drop(*columns_to_index)
train_data_indexed = train_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")
test_data_indexed = test_data_indexed.drop(*columns_to_index)
test_data_indexed = test_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")

#print("train_indexed columns: ", train_data_indexed.columns)
#print("test_indexed columns: ", test_data_indexed.columns)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 45.18978667259216 seconds

# %%
start_time = time.time()

#List of numeric column names
numeric_columns = ['resp_pkts', 
                   'orig_ip_bytes', 
                   'missed_bytes', 
                   'duration', 
                   'orig_pkts',
                   'resp_ip_bytes', 
                   'dest_port_zeek', 
                   'orig_bytes', 
                   'resp_bytes',
                   'src_port_zeek', 
                   'ts']

#Create Imputer
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

#Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data_indexed)

#Apply the Imputer to the training data
train_data_imputed = imputer_model.transform(train_data_indexed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Apply the Imputer to the test data
start_time = time.time()
test_data_imputed = imputer_model.transform(test_data_indexed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

train_data_imputed = train_data_imputed.drop(*numeric_columns)
test_data_imputed = test_data_imputed.drop(*numeric_columns)

#print("\nTrain data imputed: ", train_data_imputed.columns)
#print("\n")
#print("Test data imputed: ", test_data_imputed.columns)
# Out:
# Execution time: 3.874361753463745 seconds
# Execution time: 0.023499488830566406 seconds

# %%
start_time = time.time()

#Create VectorAssembler
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed") or column.endswith("_indexed")]
#print("Columns to assemble: ", columns_to_assemble)

assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

#Transform the training data
train_data_assembled = assembler.transform(train_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Transform the test data
start_time = time.time()
test_data_assembled = assembler.transform(test_data_imputed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Select the features and label columns
train_data_assembled = train_data_assembled.select("features", "label_tactic")
test_data_assembled = test_data_assembled.select("features", "label_tactic")

print("Train_data_assembled columns: ", train_data_assembled.columns)
print("Test_data_assembled columns: ", test_data_assembled.columns)
# Out:
# Execution time: 0.823676347732544 seconds
# Execution time: 0.31543731689453125 seconds
# Train_data_assembled columns:  ['features', 'label_tactic']
# Test_data_assembled columns:  ['features', 'label_tactic']

# %%
#Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)
ovr = OneVsRest(classifier=svm, labelCol="label_tactic")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.04250979423522949 seconds

# %%
#Fit the model
start_time = time.time()
svm_model = ovr.fit(train_data_assembled)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/06/26 15:29:47 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/06/26 15:29:49 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:29:55 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:29:57 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:01 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:03 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:05 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:07 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:08 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:10 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:12 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:13 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:15 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:17 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:18 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:20 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:22 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:23 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:25 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:27 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:28 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:30 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:31 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:32 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:34 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:36 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:37 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:39 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:41 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:42 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:44 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:45 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:47 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:48 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:49 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:51 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:53 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:54 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:56 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:57 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:30:59 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:00 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:01 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:03 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:05 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:06 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:08 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:09 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:11 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:12 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:14 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:15 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:17 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:19 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:20 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:21 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:23 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:25 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:27 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:28 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:30 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:32 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:33 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:35 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:36 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:38 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:39 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:41 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:42 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:43 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:45 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:46 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:48 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:50 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:51 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:53 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:54 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:56 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:57 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:31:59 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:00 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:02 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:03 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:05 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:06 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:08 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:09 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:11 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:12 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:14 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:15 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:17 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:18 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:19 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:21 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:23 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:24 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:25 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:27 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:28 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:30 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:31 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:32 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:34 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:35 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:37 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:38 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:39 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:41 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:42 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:44 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:45 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:47 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:48 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:50 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:52 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:53 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:55 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:56 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:58 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:32:59 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:01 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:02 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:04 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:05 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:07 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:08 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:09 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:11 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:13 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:14 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:15 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:16 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:18 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:19 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:21 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:22 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:24 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:25 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:26 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:28 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:29 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:31 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:32 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:33 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:35 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:36 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:38 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:39 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:41 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:42 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:44 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:45 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:47 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:48 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:50 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:51 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:52 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:54 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:55 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:57 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:58 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:33:59 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:01 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:02 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:04 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:05 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:07 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:08 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:10 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:11 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:12 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:14 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:15 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:17 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:18 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:19 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:21 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:22 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:24 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# Execution time: 280.81955313682556 seconds

# %%
#Make predictions
start_time = time.time()

predictions = svm_model.transform(test_data_assembled)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.5953843593597412 seconds

# %%
# Evaluate the model
# Calculate accuracy
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)

# Calculate precision
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)

# Calculate recall
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)

# Calculate F1-score
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)

#Calculate FPR
evaluator_fprL = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="falsePositiveRateByLabel")
fprL_score = evaluator_fprL.evaluate(predictions)

#Calculate Weighted FPR
evaluator_fpr = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedFalsePositiveRate")
fpr_score = evaluator_fpr.evaluate(predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
print("FPR by Label:", fprL_score)
print("Weighted FPR:", fpr_score)
# Out:
# 24/06/26 15:34:28 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:38 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:47 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:34:56 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:35:04 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:35:13 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# [Stage 257:====================================================>(117 + 1) / 118]
# Accuracy: 0.9994240847060507
# Precision: 0.9994408685519582
# Recall: 0.9994240847060507
# F1-Score: 0.9994302799307315
# FPR by Label: 0.00015727316919733495
# Weighted FPR: 0.0003100058960656541

# %%
start_time = time.time()

#Extract predictions and labels
predictions_and_labels = predictions.select("prediction", "label_tactic")

#Calculate false positives and true negatives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic== 0)).count()
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic == 0)).count()

#Calculate FPR
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/06/26 15:35:21 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:35:29 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# [Stage 262:====================================================>(117 + 1) / 118]
# False Positive Rate: 0.000308027335635181
# Execution time: 16.15259599685669 seconds

# %%
from pyspark.mllib.evaluation import BinaryClassificationMetrics
from pyspark.sql import Row

# Convert DataFrame to RDD of tuples (prediction, label)
prediction_and_labels = predictions.select("prediction", "label_tactic") \
    .rdd.map(lambda row: (float(row['prediction']), float(row['label_tactic'])))


# Instantiate BinaryClassificationMetrics
metrics = BinaryClassificationMetrics(prediction_and_labels)

# Compute AUROC
auROC = metrics.areaUnderROC

# Print AUROC
print("Area under ROC = ", auROC)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/pyspark/sql/context.py:158: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# 24/06/26 15:35:38 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:35:39 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# 24/06/26 15:35:41 WARN DAGScheduler: Broadcasting large task binary with size 21.5 MiB
# Area under ROC =  0.9992465214818406

# %%
spark.sparkContext.stop()
