# %%
# PySpark Imports
import pyspark
from pyspark.sql import SparkSession

# ML Classifier Imports
from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import mean, col
import time
import os
import sys

# %%
# Initialize Spark session
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.memory", "14g") \
    .config("spark.executor.memory", "14g") \
    .config("spark.executor.cores", "2") \
    .config("spark.dynamicAllocation.shuffleTracking.enabled", "true") \
    .config("spark.dynamicAllocation.enabled", "true") \
    .config("spark.dynamicAllocation.minExecutors", "2") \
    .config("spark.dynamicAllocation.maxExecutors", "2") \
    .config("spark.executor.instances", "2") \
    .config("spark.kryoserializer.buffer.max", "2047m") \
    .config("spark.sql.execution.pythonUDF.arrow.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/04/11 05:27:08 WARN Utils: Your hostname, colin-MS-7977 resolves to a loopback address: 127.0.1.1; using 192.168.0.164 instead (on interface wlx3c52a1d3ccda)
# 24/04/11 05:27:08 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/11 05:27:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
parquet_files = ["Parquet/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet", "Parquet/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet", 
                 "Parquet/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet", "Parquet/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "Parquet/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet", "Parquet/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "Parquet/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet", "Parquet/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet"]

# %%
# Read the parquet files into a dataframe
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
# Get unique labels and their counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the results
label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
start_time = time.time()

# List of labels to drop
labels_to_drop = ["Defense Evasion", "Exfiltration", "Initial Access", "Lateral Movement", "Persistence", "Privilege Escalation", "Resource Development", "Credential Access", "Reconnaissance"]

# Filter out the rows with labels to drop
df = df.filter(~col("label_tactic").isin(labels_to_drop))

# Get unique labels and their counts after filtering
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the filtered results
filtered_label_counts.show()


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# +------------+-------+
# |label_tactic|  count|
# +------------+-------+
# |   Discovery|   2086|
# |        none|9281599|
# +------------+-------+
#
# Execution time: 0.8637042045593262 seconds

# %%
start_time = time.time()



df = df.withColumn("datetime", col("datetime").cast("string"))

# Define columns to index
columns_to_index = ['service', 'conn_state', 'history', 'proto', 'dest_ip_zeek', 'community_id', 'uid', 'src_ip_zeek', 'label_tactic', 'datetime']

# Impute null values with 'null' string
for column in columns_to_index:
    df = df.fillna('null', subset=[column])

# Apply StringIndexer to each column
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").fit(df) for column in columns_to_index]

# Chain indexers together
pipeline = Pipeline(stages=indexers)

# Fit and transform the data
df_indexed = pipeline.fit(df).transform(df)

# Drop original columns
df_indexed = df_indexed.drop(*columns_to_index)

# Show the schema of the DataFrame
#df_indexed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 47.10861849784851 seconds

# %%
# Split the data into training and test sets
start_time = time.time()

train_data, test_data = df_indexed.randomSplit([0.7, 0.3], seed=42)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.016680002212524414 seconds

# %%
from pyspark.ml.feature import Imputer


start_time = time.time()

# List of numeric column names
numeric_columns = ['resp_pkts', 'orig_ip_bytes', 'missed_bytes', 'duration', 'orig_pkts',
                   'resp_ip_bytes', 'dest_port_zeek', 'orig_bytes', 'resp_bytes',
                   'src_port_zeek', 'ts']


# Create an Imputer object
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

# Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data)

# Apply the imputer to the training data
train_data_imputed = imputer_model.transform(train_data)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()


# Apply the imputer to the test data
test_data_imputed = imputer_model.transform(test_data)

# Show updated DataFrames
#train_data_imputed.show()
#test_data_imputed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/11 05:28:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Execution time: 41.188814640045166 seconds
# Execution time: 0.021237611770629883 seconds

# %%
from pyspark.ml.feature import VectorAssembler


start_time = time.time()



# List of columns to assemble
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed")]

# Create the VectorAssembler
assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

# Transform the training DataFrame
train_data_assembled = assembler.transform(train_data_imputed)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
# Transform the test DataFrame
test_data_assembled = assembler.transform(test_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Select only the features and label columns for both training and test sets
train_data_assembled = train_data_assembled.select("features", "label_tactic_indexed")
test_data_assembled = test_data_assembled.select("features", "label_tactic_indexed")

# Show the schema of the assembled training DataFrame
#train_data_assembled.printSchema()

# Show the schema of the assembled test DataFrame
#test_data_assembled.printSchema()
# Out:
# Execution time: 5.0391457080841064 seconds
# Execution time: 0.07137274742126465 seconds

# %%
from pyspark.ml.feature import StandardScaler


start_time = time.time()

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/11 05:29:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:29:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 45:>                                                         (0 + 1) / 1]
# Execution time: 61.61351680755615 seconds

# %%
start_time = time.time()


# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.03572440147399902 seconds

# %%
# Define the PCA model
pca = PCA(k=5, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/11 05:30:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:30:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:31:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:31:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:32:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:32:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:32:52 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/04/11 05:33:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 52:>                                                         (0 + 2) / 2]
# Execution time: 207.5953917503357 seconds
# 24/04/11 05:33:19 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK

# %%
# Apply PCA transformation to the training and test sets

start_time = time.time()
train_pca = pca_model.transform(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
test_pca = pca_model.transform(test_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.04823756217956543 seconds
# Execution time: 0.017632246017456055 seconds

# %%
# Drop the normalized column and rename the pca_features column
start_time = time.time()
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

start_time = time.time()
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Verify the changes
#train_pca.show()
#test_pca.show()
# Out:
# Execution time: 0.013806819915771484 seconds
# Execution time: 0.012786626815795898 seconds

# %%
# Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic_indexed", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)

# One Vs. Rest
ovr = OneVsRest(classifier=svm, labelCol='label_tactic_indexed')

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Fit the model
start_time = time.time()

svm_model = ovr.fit(train_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.09632182121276855 seconds
# 24/04/11 05:33:33 WARN DAGScheduler: Broadcasting large task binary with size 265.9 MiB
# 24/04/11 05:34:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:35:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:35:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:35:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:36:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:36:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:36:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:37:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:37:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:37:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:38:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:38:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:38:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:39:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:39:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:39:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:40:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:40:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:40:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:40:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:41:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:41:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:41:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:42:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:42:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:42:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:43:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:43:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:43:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:44:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:44:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:44:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:45:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:45:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:45:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:45:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:46:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:46:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:46:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:47:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:47:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:47:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:47:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:48:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:48:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:48:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:49:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:49:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:49:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:49:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:50:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:50:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:50:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:51:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:51:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:51:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:51:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:52:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:52:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:52:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:52:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:53:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:53:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:53:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:54:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:54:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:54:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:54:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:55:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:55:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:55:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:56:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:56:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:56:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:56:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:57:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:57:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:57:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:58:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:58:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:58:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:58:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:59:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:59:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 05:59:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:00:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:00:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:00:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:00:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:01:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:01:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:01:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:02:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:02:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:02:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:03:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:03:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:03:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:03:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:04:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:04:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:04:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:05:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:05:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:05:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:05:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:06:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:06:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:06:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:07:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:07:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:07:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:07:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:08:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:08:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:08:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:08:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:09:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:09:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:09:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:10:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:10:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:10:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:10:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:11:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:11:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:11:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:12:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:12:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:12:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:12:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:13:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:13:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:13:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:14:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:14:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:14:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:14:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:15:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:15:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:15:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:15:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:16:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:16:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:16:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:17:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:17:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:17:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:17:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:18:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:18:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:18:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:19:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:19:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:19:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:19:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:20:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:20:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:20:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:21:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:21:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:21:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:21:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:22:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:22:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:22:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:23:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:23:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:23:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:23:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:24:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:24:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:24:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:25:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:25:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:25:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:25:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:26:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:26:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:26:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:27:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:27:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:27:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:27:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:28:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:28:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:28:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:29:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:29:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:29:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:29:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:30:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:30:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:30:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:31:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:31:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:31:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:31:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:32:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:32:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:32:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:33:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:33:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:33:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:33:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:34:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:34:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:34:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:35:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:35:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:35:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:35:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:36:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:36:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:36:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:37:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:37:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Execution time: 3845.3968126773834 seconds

# %%
# Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.24994444847106934 seconds

# %%
# Evaluate the model
# Calculate accuracy
start_time = time.time()
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)
print("Accuracy:", accuracy)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate precision
start_time = time.time()
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)
print("Precision:", precision)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate recall
start_time = time.time()
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)
print("Recall:", recall)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate F1-score
start_time = time.time()
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)
print("F1-Score:", f1_score)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
# Out:
# 24/04/11 06:37:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Accuracy: 0.9997616284225079
# Execution time: 79.10963320732117 seconds
# 24/04/11 06:39:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Precision: 0.9995233136660248
# Execution time: 74.88405966758728 seconds
# 24/04/11 06:40:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Recall: 0.9997616284225079
# Execution time: 74.09808993339539 seconds
# 24/04/11 06:41:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 279:=================================================>       (7 + 1) / 8]
# F1-Score: 0.9996424568407074
# Execution time: 74.49236798286438 seconds
# Accuracy: 0.9997616284225079
# Precision: 0.9995233136660248
# Recall: 0.9997616284225079
# F1-Score: 0.9996424568407074

# %%
from pyspark.sql.functions import expr

start_time = time.time()

# Extract Predictions and True Labels
predictions_and_labels = predictions.select("prediction", "label_tactic_indexed")

# Calculate False Positives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate True Negatives
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate False Positive Rate (FPR)
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/11 06:42:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/11 06:44:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 284:=================================================>       (7 + 1) / 8]
# False Positive Rate: 0.0
# Execution time: 150.25729632377625 seconds

# %%
spark.sparkContext.stop()
