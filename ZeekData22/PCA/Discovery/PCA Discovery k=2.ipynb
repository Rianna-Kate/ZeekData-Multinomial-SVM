# %%
# PySpark Imports
import pyspark
from pyspark.sql import SparkSession

# ML Classifier Imports
from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import mean, col
import time
import os
import sys

# %%
# Initialize Spark session
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.memory", "14g") \
    .config("spark.executor.memory", "14g") \
    .config("spark.executor.cores", "2") \
    .config("spark.dynamicAllocation.shuffleTracking.enabled", "true") \
    .config("spark.dynamicAllocation.enabled", "true") \
    .config("spark.dynamicAllocation.minExecutors", "2") \
    .config("spark.dynamicAllocation.maxExecutors", "2") \
    .config("spark.executor.instances", "2") \
    .config("spark.kryoserializer.buffer.max", "2047m") \
    .config("spark.sql.execution.pythonUDF.arrow.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/04/14 23:35:44 WARN Utils: Your hostname, colin-MS-7977 resolves to a loopback address: 127.0.1.1; using 192.168.0.164 instead (on interface wlx3c52a1d3ccda)
# 24/04/14 23:35:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/14 23:35:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
parquet_files = ["Parquet/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet", "Parquet/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet", 
                 "Parquet/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet", "Parquet/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "Parquet/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet", "Parquet/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "Parquet/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet", "Parquet/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet"]

# %%
# Read the parquet files into a dataframe
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
# Get unique labels and their counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the results
label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
start_time = time.time()

# List of labels to drop
labels_to_drop = ["Defense Evasion", "Exfiltration", "Initial Access", "Lateral Movement", "Persistence", "Privilege Escalation", "Resource Development", "Credential Access", "Reconnaissance"]

# Filter out the rows with labels to drop
df = df.filter(~col("label_tactic").isin(labels_to_drop))

# Get unique labels and their counts after filtering
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the filtered results
filtered_label_counts.show()


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# +------------+-------+
# |label_tactic|  count|
# +------------+-------+
# |   Discovery|   2086|
# |        none|9281599|
# +------------+-------+
#
# Execution time: 0.9071028232574463 seconds

# %%
start_time = time.time()



df = df.withColumn("datetime", col("datetime").cast("string"))

# Define columns to index
columns_to_index = ['service', 'conn_state', 'history', 'proto', 'dest_ip_zeek', 'community_id', 'uid', 'src_ip_zeek', 'label_tactic', 'datetime']

# Impute null values with 'null' string
for column in columns_to_index:
    df = df.fillna('null', subset=[column])

# Apply StringIndexer to each column
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").fit(df) for column in columns_to_index]

# Chain indexers together
pipeline = Pipeline(stages=indexers)

# Fit and transform the data
df_indexed = pipeline.fit(df).transform(df)

# Drop original columns
df_indexed = df_indexed.drop(*columns_to_index)

# Show the schema of the DataFrame
#df_indexed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 51.2852840423584 seconds

# %%
# Split the data into training and test sets
start_time = time.time()

train_data, test_data = df_indexed.randomSplit([0.7, 0.3], seed=42)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.023249149322509766 seconds

# %%
from pyspark.ml.feature import Imputer


start_time = time.time()

# List of numeric column names
numeric_columns = ['resp_pkts', 'orig_ip_bytes', 'missed_bytes', 'duration', 'orig_pkts',
                   'resp_ip_bytes', 'dest_port_zeek', 'orig_bytes', 'resp_bytes',
                   'src_port_zeek', 'ts']


# Create an Imputer object
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

# Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data)

# Apply the imputer to the training data
train_data_imputed = imputer_model.transform(train_data)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()


# Apply the imputer to the test data
test_data_imputed = imputer_model.transform(test_data)

# Show updated DataFrames
#train_data_imputed.show()
#test_data_imputed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/14 23:36:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 37:==================================================>       (7 + 1) / 8]
# Execution time: 42.83247637748718 seconds
# Execution time: 0.019525766372680664 seconds

# %%
from pyspark.ml.feature import VectorAssembler


start_time = time.time()



# List of columns to assemble
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed")]

# Create the VectorAssembler
assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

# Transform the training DataFrame
train_data_assembled = assembler.transform(train_data_imputed)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
# Transform the test DataFrame
test_data_assembled = assembler.transform(test_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Select only the features and label columns for both training and test sets
train_data_assembled = train_data_assembled.select("features", "label_tactic_indexed")
test_data_assembled = test_data_assembled.select("features", "label_tactic_indexed")

# Show the schema of the assembled training DataFrame
#train_data_assembled.printSchema()

# Show the schema of the assembled test DataFrame
#test_data_assembled.printSchema()
# Out:
# Execution time: 5.665836334228516 seconds
# Execution time: 0.07833266258239746 seconds

# %%
from pyspark.ml.feature import StandardScaler


start_time = time.time()

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/14 23:37:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:38:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 45:>                                                         (0 + 1) / 1]
# Execution time: 65.44776582717896 seconds

# %%
start_time = time.time()


# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.033470869064331055 seconds

# %%
# Define the PCA model
pca = PCA(k=2, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/14 23:39:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:39:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:40:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:40:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:41:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:41:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:41:43 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/04/14 23:42:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:42:10 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK
# Execution time: 210.23177480697632 seconds

# %%
# Apply PCA transformation to the training and test sets

start_time = time.time()
train_pca = pca_model.transform(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
test_pca = pca_model.transform(test_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.03727602958679199 seconds
# Execution time: 0.014708995819091797 seconds

# %%
# Drop the normalized column and rename the pca_features column
start_time = time.time()
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

start_time = time.time()
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Verify the changes
#train_pca.show()
#test_pca.show()
# Out:
# Execution time: 0.012357473373413086 seconds
# Execution time: 0.010076761245727539 seconds

# %%
# Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic_indexed", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)

# One Vs. Rest
ovr = OneVsRest(classifier=svm, labelCol='label_tactic_indexed')

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Fit the model
start_time = time.time()

svm_model = ovr.fit(train_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.10073995590209961 seconds
# 24/04/14 23:42:22 WARN DAGScheduler: Broadcasting large task binary with size 265.9 MiB
# 24/04/14 23:43:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:43:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:44:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:44:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:44:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:45:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:45:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:45:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:45:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:46:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:46:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:46:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:47:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:47:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:47:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:48:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:48:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:48:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:49:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:49:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:49:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:49:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:50:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:50:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:50:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:51:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:51:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:51:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:52:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:52:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:52:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:53:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:53:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:53:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:54:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:54:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:54:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:55:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:55:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:55:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:56:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:56:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:56:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:56:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:57:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:57:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:57:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:58:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:58:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:58:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:59:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:59:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:59:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/14 23:59:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:00:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:00:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:00:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:01:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:01:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:01:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:02:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:02:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:02:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:02:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:03:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:03:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:03:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:04:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:04:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:04:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:05:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:05:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:05:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:05:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:06:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:06:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:06:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:07:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:07:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:07:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:07:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:08:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:08:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:08:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:09:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:09:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:09:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:09:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:10:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:10:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:11:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:11:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:11:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:11:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:12:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:12:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:12:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:13:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:13:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:13:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:14:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:14:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:14:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:15:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:15:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:15:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:16:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:16:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:16:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:16:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:17:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:17:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:17:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:18:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:18:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:18:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:18:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:19:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:19:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:19:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:20:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:20:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:20:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:20:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:21:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:21:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:21:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:21:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:22:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:22:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:22:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:22:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:23:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:23:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:23:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:24:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:24:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:24:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:25:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:25:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:25:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:25:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:26:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:26:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:26:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:27:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:27:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:27:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:28:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:28:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:28:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:28:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:29:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:29:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:29:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:30:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:30:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:30:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:30:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:31:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:31:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:31:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:32:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:32:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:32:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:32:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:33:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:33:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:33:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:34:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:34:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:34:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:35:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:35:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:35:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:36:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:36:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:36:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:36:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:37:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:37:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:37:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:38:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:38:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:38:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:39:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:39:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:39:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:39:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:40:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:40:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:40:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:41:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:41:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:42:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:42:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:42:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:42:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:43:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:43:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:43:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:44:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:44:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:44:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:44:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:45:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:45:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:45:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:46:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:46:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:46:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:47:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:47:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:47:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:47:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:48:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:48:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:48:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:49:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:49:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:49:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:50:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:50:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:50:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:50:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:51:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:51:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:51:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:52:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:52:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:52:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 00:53:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Execution time: 4256.534117221832 seconds

# %%
# Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.3334627151489258 seconds

# %%
# Evaluate the model
# Calculate accuracy
start_time = time.time()
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)
print("Accuracy:", accuracy)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate precision
start_time = time.time()
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)
print("Precision:", precision)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate recall
start_time = time.time()
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)
print("Recall:", recall)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate F1-score
start_time = time.time()
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)
print("F1-Score:", f1_score)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
# Out:
# 24/04/15 00:53:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Accuracy: 0.9997616284225079
# Execution time: 82.704270362854 seconds
# 24/04/15 00:54:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Precision: 0.9995233136660248
# Execution time: 76.7992775440216 seconds
# 24/04/15 00:56:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Recall: 0.9997616284225079
# Execution time: 81.39093732833862 seconds
# 24/04/15 00:57:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 295:=================================================>       (7 + 1) / 8]
# F1-Score: 0.9996424568407074
# Execution time: 79.87306380271912 seconds
# Accuracy: 0.9997616284225079
# Precision: 0.9995233136660248
# Recall: 0.9997616284225079
# F1-Score: 0.9996424568407074

# %%
from pyspark.sql.functions import expr

start_time = time.time()

# Extract Predictions and True Labels
predictions_and_labels = predictions.select("prediction", "label_tactic_indexed")

# Calculate False Positives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate True Negatives
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate False Positive Rate (FPR)
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/15 00:58:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 01:00:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 300:=================================================>       (7 + 1) / 8]
# False Positive Rate: 0.0
# Execution time: 159.61669969558716 seconds

# %%
spark.sparkContext.stop()
