# %%
# PySpark Imports
import pyspark
from pyspark.sql import SparkSession

# ML Classifier Imports
from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import mean, col
import time
import os
import sys

# %%
# Initialize Spark session
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.memory", "14g") \
    .config("spark.executor.memory", "14g") \
    .config("spark.executor.cores", "2") \
    .config("spark.dynamicAllocation.shuffleTracking.enabled", "true") \
    .config("spark.dynamicAllocation.enabled", "true") \
    .config("spark.dynamicAllocation.minExecutors", "2") \
    .config("spark.dynamicAllocation.maxExecutors", "2") \
    .config("spark.executor.instances", "2") \
    .config("spark.kryoserializer.buffer.max", "2047m") \
    .config("spark.sql.execution.pythonUDF.arrow.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/04/10 21:18:08 WARN Utils: Your hostname, colin-MS-7977 resolves to a loopback address: 127.0.1.1; using 192.168.0.164 instead (on interface wlx3c52a1d3ccda)
# 24/04/10 21:18:08 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/10 21:18:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
parquet_files = ["Parquet/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet", "Parquet/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet", 
                 "Parquet/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet", "Parquet/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "Parquet/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet", "Parquet/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "Parquet/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet", "Parquet/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet"]

# %%
# Read the parquet files into a dataframe
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
# Get unique labels and their counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the results
label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
start_time = time.time()

# List of labels to drop
labels_to_drop = ["Defense Evasion", "Exfiltration", "Initial Access", "Lateral Movement", "Persistence", "Privilege Escalation", "Resource Development", "Credential Access", "Reconnaissance"]

# Filter out the rows with labels to drop
df = df.filter(~col("label_tactic").isin(labels_to_drop))

# Get unique labels and their counts after filtering
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the filtered results
filtered_label_counts.show()


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# +------------+-------+
# |label_tactic|  count|
# +------------+-------+
# |   Discovery|   2086|
# |        none|9281599|
# +------------+-------+
#
# Execution time: 0.930394172668457 seconds

# %%
start_time = time.time()



df = df.withColumn("datetime", col("datetime").cast("string"))

# Define columns to index
columns_to_index = ['service', 'conn_state', 'history', 'proto', 'dest_ip_zeek', 'community_id', 'uid', 'src_ip_zeek', 'label_tactic', 'datetime']

# Impute null values with 'null' string
for column in columns_to_index:
    df = df.fillna('null', subset=[column])

# Apply StringIndexer to each column
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").fit(df) for column in columns_to_index]

# Chain indexers together
pipeline = Pipeline(stages=indexers)

# Fit and transform the data
df_indexed = pipeline.fit(df).transform(df)

# Drop original columns
df_indexed = df_indexed.drop(*columns_to_index)

# Show the schema of the DataFrame
#df_indexed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 59.32519054412842 seconds

# %%
# Split the data into training and test sets
start_time = time.time()

train_data, test_data = df_indexed.randomSplit([0.7, 0.3], seed=42)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.021856307983398438 seconds

# %%
from pyspark.ml.feature import Imputer


start_time = time.time()

# List of numeric column names
numeric_columns = ['resp_pkts', 'orig_ip_bytes', 'missed_bytes', 'duration', 'orig_pkts',
                   'resp_ip_bytes', 'dest_port_zeek', 'orig_bytes', 'resp_bytes',
                   'src_port_zeek', 'ts']


# Create an Imputer object
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

# Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data)

# Apply the imputer to the training data
train_data_imputed = imputer_model.transform(train_data)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()


# Apply the imputer to the test data
test_data_imputed = imputer_model.transform(test_data)

# Show updated DataFrames
#train_data_imputed.show()
#test_data_imputed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/10 21:19:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Execution time: 48.06410264968872 seconds
# Execution time: 0.029091358184814453 seconds

# %%
from pyspark.ml.feature import VectorAssembler


start_time = time.time()



# List of columns to assemble
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed")]

# Create the VectorAssembler
assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

# Transform the training DataFrame
train_data_assembled = assembler.transform(train_data_imputed)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
# Transform the test DataFrame
test_data_assembled = assembler.transform(test_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Select only the features and label columns for both training and test sets
train_data_assembled = train_data_assembled.select("features", "label_tactic_indexed")
test_data_assembled = test_data_assembled.select("features", "label_tactic_indexed")

# Show the schema of the assembled training DataFrame
#train_data_assembled.printSchema()

# Show the schema of the assembled test DataFrame
#test_data_assembled.printSchema()
# Out:
# Execution time: 5.698318004608154 seconds
# Execution time: 0.09439539909362793 seconds

# %%
from pyspark.ml.feature import StandardScaler


start_time = time.time()

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/10 21:20:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:21:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 45:>                                                         (0 + 1) / 1]
# Execution time: 72.66529321670532 seconds

# %%
start_time = time.time()


# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.031154155731201172 seconds

# %%
# Define the PCA model
pca = PCA(k=11, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/10 21:21:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:22:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:22:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:23:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:23:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:24:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:24:33 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/04/10 21:25:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 52:>                                                         (0 + 2) / 2]
# Execution time: 222.7357246875763 seconds
# 24/04/10 21:25:08 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK

# %%
# Apply PCA transformation to the training and test sets

start_time = time.time()
train_pca = pca_model.transform(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
test_pca = pca_model.transform(test_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.033551931381225586 seconds
# Execution time: 0.01350855827331543 seconds

# %%
# Drop the normalized column and rename the pca_features column
start_time = time.time()
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

start_time = time.time()
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Verify the changes
#train_pca.show()
#test_pca.show()
# Out:
# Execution time: 0.010976552963256836 seconds
# Execution time: 0.008396387100219727 seconds

# %%
# Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic_indexed", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)

# One Vs. Rest
ovr = OneVsRest(classifier=svm, labelCol='label_tactic_indexed')

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Fit the model
start_time = time.time()

svm_model = ovr.fit(train_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.07958412170410156 seconds
# 24/04/10 21:25:21 WARN DAGScheduler: Broadcasting large task binary with size 265.9 MiB
# 24/04/10 21:26:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:27:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:27:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:27:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:28:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:28:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:29:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:29:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:29:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:30:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:30:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:30:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:31:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:31:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:31:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:32:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:32:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:32:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:33:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:33:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:33:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:34:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:34:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:34:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:35:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:35:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:35:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:36:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:36:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:36:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:37:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:37:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:37:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:38:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:38:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:38:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:39:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:39:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:39:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:40:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:40:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:40:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:41:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:41:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:41:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:42:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:42:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:42:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:43:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:43:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:43:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:44:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:44:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:44:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:45:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:45:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:45:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:45:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:46:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:46:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:46:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:47:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:47:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:47:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:47:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:48:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:48:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:48:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:49:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:49:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:49:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:49:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:50:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:50:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:50:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:50:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:51:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:51:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:51:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:51:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:52:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:52:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:52:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:53:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:53:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:53:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:53:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:54:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:54:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:54:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:55:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:55:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:55:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:55:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:56:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:56:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:56:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:57:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:57:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:57:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:57:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:58:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:58:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:58:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:59:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:59:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:59:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 21:59:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:00:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:00:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:00:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:00:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:01:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:01:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:01:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:02:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:02:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:02:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:02:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:03:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:03:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:03:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:03:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:04:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:04:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:04:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:05:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:05:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:05:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:05:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:06:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:06:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:06:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:06:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:07:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:07:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:07:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:08:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:08:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:08:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:08:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:09:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:09:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:09:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:10:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:10:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:10:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:10:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:11:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:11:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:11:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:11:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:12:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:12:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:12:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:13:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:13:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:13:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:13:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:14:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:14:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:14:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:15:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:15:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:15:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:15:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:16:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:16:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:16:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:16:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:17:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:17:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:17:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:18:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:18:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:18:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:18:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:19:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:19:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:19:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:19:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:20:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:20:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:20:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:21:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:21:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:21:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:21:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:22:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:22:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:22:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:23:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:23:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:23:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:23:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:24:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:24:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:24:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:24:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:25:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:25:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:25:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:26:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:26:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:26:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:26:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:27:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:27:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:27:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:28:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:28:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:28:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:28:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:29:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:29:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:29:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:29:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:30:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:30:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:30:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:30:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:31:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:31:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:31:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:32:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:32:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:32:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:32:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:33:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:33:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:33:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:33:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:34:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:34:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:34:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:35:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:35:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:35:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:35:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:36:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:36:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:36:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:37:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:37:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:37:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:37:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:38:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:38:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:38:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:38:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:39:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:39:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:39:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:40:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:40:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:40:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:40:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:41:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:41:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:41:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:42:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:42:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:42:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:42:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:43:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 320:>                                                        (0 + 2) / 2]
# Execution time: 4681.788947343826 seconds

# %%
# Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.32515668869018555 seconds

# %%
# Evaluate the model
# Calculate accuracy
start_time = time.time()
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)
print("Accuracy:", accuracy)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate precision
start_time = time.time()
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)
print("Precision:", precision)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate recall
start_time = time.time()
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)
print("Recall:", recall)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate F1-score
start_time = time.time()
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)
print("F1-Score:", f1_score)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
# Out:
# 24/04/10 22:43:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Accuracy: 1.0
# Execution time: 79.77866125106812 seconds
# 24/04/10 22:44:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Precision: 1.0
# Execution time: 74.97454118728638 seconds
# 24/04/10 22:46:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Recall: 1.0
# Execution time: 75.47448205947876 seconds
# 24/04/10 22:47:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 327:=================================================>       (7 + 1) / 8]
# F1-Score: 1.0
# Execution time: 75.69667434692383 seconds
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0

# %%
from pyspark.sql.functions import expr

start_time = time.time()

# Extract Predictions and True Labels
predictions_and_labels = predictions.select("prediction", "label_tactic_indexed")

# Calculate False Positives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate True Negatives
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate False Positive Rate (FPR)
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/10 22:48:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/10 22:49:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 332:=================================================>       (7 + 1) / 8]
# False Positive Rate: 0.0
# Execution time: 152.1333031654358 seconds

# %%
spark.sparkContext.stop()
