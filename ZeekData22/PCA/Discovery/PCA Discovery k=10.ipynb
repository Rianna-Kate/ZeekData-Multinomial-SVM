# %%
# PySpark Imports
import pyspark
from pyspark.sql import SparkSession

# ML Classifier Imports
from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import mean, col
import time
import os
import sys

# %%
# Initialize Spark session
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.memory", "14g") \
    .config("spark.executor.memory", "14g") \
    .config("spark.executor.cores", "2") \
    .config("spark.dynamicAllocation.shuffleTracking.enabled", "true") \
    .config("spark.dynamicAllocation.enabled", "true") \
    .config("spark.dynamicAllocation.minExecutors", "2") \
    .config("spark.dynamicAllocation.maxExecutors", "2") \
    .config("spark.executor.instances", "2") \
    .config("spark.kryoserializer.buffer.max", "2047m") \
    .config("spark.sql.execution.pythonUDF.arrow.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/04/15 09:05:39 WARN Utils: Your hostname, colin-MS-7977 resolves to a loopback address: 127.0.1.1; using 192.168.0.164 instead (on interface wlx3c52a1d3ccda)
# 24/04/15 09:05:39 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/15 09:05:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
parquet_files = ["Parquet/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet", "Parquet/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet", 
                 "Parquet/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet", "Parquet/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "Parquet/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet", "Parquet/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "Parquet/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet", "Parquet/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet"]

# %%
# Read the parquet files into a dataframe
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
# Get unique labels and their counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the results
label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
start_time = time.time()

# List of labels to drop
labels_to_drop = ["Defense Evasion", "Exfiltration", "Initial Access", "Lateral Movement", "Persistence", "Privilege Escalation", "Resource Development", "Credential Access", "Reconnaissance"]

# Filter out the rows with labels to drop
df = df.filter(~col("label_tactic").isin(labels_to_drop))

# Get unique labels and their counts after filtering
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the filtered results
filtered_label_counts.show()


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# [Stage 4:======================>                                    (3 + 5) / 8]
# +------------+-------+
# |label_tactic|  count|
# +------------+-------+
# |   Discovery|   2086|
# |        none|9281599|
# +------------+-------+
#
# Execution time: 1.0003278255462646 seconds

# %%
start_time = time.time()



df = df.withColumn("datetime", col("datetime").cast("string"))

# Define columns to index
columns_to_index = ['service', 'conn_state', 'history', 'proto', 'dest_ip_zeek', 'community_id', 'uid', 'src_ip_zeek', 'label_tactic', 'datetime']

# Impute null values with 'null' string
for column in columns_to_index:
    df = df.fillna('null', subset=[column])

# Apply StringIndexer to each column
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").fit(df) for column in columns_to_index]

# Chain indexers together
pipeline = Pipeline(stages=indexers)

# Fit and transform the data
df_indexed = pipeline.fit(df).transform(df)

# Drop original columns
df_indexed = df_indexed.drop(*columns_to_index)

# Show the schema of the DataFrame
#df_indexed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 48.59970021247864 seconds

# %%
# Split the data into training and test sets
start_time = time.time()

train_data, test_data = df_indexed.randomSplit([0.7, 0.3], seed=42)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.017121315002441406 seconds

# %%
from pyspark.ml.feature import Imputer


start_time = time.time()

# List of numeric column names
numeric_columns = ['resp_pkts', 'orig_ip_bytes', 'missed_bytes', 'duration', 'orig_pkts',
                   'resp_ip_bytes', 'dest_port_zeek', 'orig_bytes', 'resp_bytes',
                   'src_port_zeek', 'ts']


# Create an Imputer object
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

# Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data)

# Apply the imputer to the training data
train_data_imputed = imputer_model.transform(train_data)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()


# Apply the imputer to the test data
test_data_imputed = imputer_model.transform(test_data)

# Show updated DataFrames
#train_data_imputed.show()
#test_data_imputed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/15 09:06:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Execution time: 40.5656054019928 seconds
# Execution time: 0.025330066680908203 seconds

# %%
from pyspark.ml.feature import VectorAssembler


start_time = time.time()



# List of columns to assemble
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed")]

# Create the VectorAssembler
assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

# Transform the training DataFrame
train_data_assembled = assembler.transform(train_data_imputed)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
# Transform the test DataFrame
test_data_assembled = assembler.transform(test_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Select only the features and label columns for both training and test sets
train_data_assembled = train_data_assembled.select("features", "label_tactic_indexed")
test_data_assembled = test_data_assembled.select("features", "label_tactic_indexed")

# Show the schema of the assembled training DataFrame
#train_data_assembled.printSchema()

# Show the schema of the assembled test DataFrame
#test_data_assembled.printSchema()
# Out:
# Execution time: 4.397993564605713 seconds
# Execution time: 0.0777585506439209 seconds

# %%
from pyspark.ml.feature import StandardScaler


start_time = time.time()

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/15 09:07:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:08:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 45:>                                                         (0 + 1) / 1]
# Execution time: 65.93828582763672 seconds

# %%
start_time = time.time()


# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.025814294815063477 seconds

# %%
# Define the PCA model
pca = PCA(k=10, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/15 09:08:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:09:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:09:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:10:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:10:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:11:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:11:27 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/04/15 09:11:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 52:>                                                         (0 + 2) / 2]
# Execution time: 207.10579895973206 seconds
# 24/04/15 09:11:54 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK

# %%
# Apply PCA transformation to the training and test sets

start_time = time.time()
train_pca = pca_model.transform(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
test_pca = pca_model.transform(test_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.03379535675048828 seconds
# Execution time: 0.011785745620727539 seconds

# %%
# Drop the normalized column and rename the pca_features column
start_time = time.time()
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

start_time = time.time()
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Verify the changes
#train_pca.show()
#test_pca.show()
# Out:
# Execution time: 0.009531736373901367 seconds
# Execution time: 0.008253812789916992 seconds

# %%
# Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic_indexed", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)

# One Vs. Rest
ovr = OneVsRest(classifier=svm, labelCol='label_tactic_indexed')

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Fit the model
start_time = time.time()

svm_model = ovr.fit(train_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.01415705680847168 seconds
# 24/04/15 09:12:05 WARN DAGScheduler: Broadcasting large task binary with size 265.9 MiB
# 24/04/15 09:12:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:13:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:14:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:14:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:14:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:14:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:15:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:15:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:15:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:16:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:16:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:16:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:16:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:17:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:17:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:17:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:18:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:18:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:18:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:19:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:19:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:19:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:19:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:20:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:20:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:20:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:21:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:21:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:21:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:21:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:22:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:22:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:22:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:23:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:23:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:23:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:23:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:24:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:24:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:24:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:25:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:25:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:25:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:26:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:26:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:26:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:27:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:27:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:27:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:28:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:28:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:28:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:29:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:29:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:29:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:30:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:30:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:30:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:31:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:31:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:31:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:32:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:32:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:32:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:33:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:33:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:33:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:34:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:34:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:34:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:35:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:35:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:36:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:36:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:36:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:37:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:37:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:37:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:38:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:38:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:38:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:39:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:39:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:40:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:40:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:40:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:41:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:41:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:41:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:42:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:42:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:42:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:43:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:43:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:43:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:44:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:44:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:44:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:45:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:45:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:46:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:46:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:46:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:47:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:47:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:47:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:48:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:48:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:48:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:49:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:49:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:49:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:50:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:50:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:50:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:51:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:51:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:51:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:51:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:52:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:52:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:52:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:53:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:53:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:53:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:54:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:54:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:54:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:55:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:55:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:55:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:56:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:56:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:56:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:57:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:57:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:57:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:58:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:58:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:58:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:59:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:59:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 09:59:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:00:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:00:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:00:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:00:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:01:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:01:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:01:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:02:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:02:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:02:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:03:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:03:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:03:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:04:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:04:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:04:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:05:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:05:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:05:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:06:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:06:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:06:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:07:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:07:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:08:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:08:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:08:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:09:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:09:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:09:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:10:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:10:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:10:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:11:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:11:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:11:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:12:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:12:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:12:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:13:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:13:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:13:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:14:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:14:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:14:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:15:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:15:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:15:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:16:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:16:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:16:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:17:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:17:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:17:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:18:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:18:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:18:48 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:19:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:19:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:19:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:20:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:20:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:20:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:21:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:21:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:22:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:22:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:22:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:23:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:23:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:23:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:24:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:24:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:24:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:25:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:25:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:25:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:26:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:26:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:26:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:27:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:27:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:28:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:28:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:28:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:29:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:29:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:29:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:30:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:30:21 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:30:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:31:00 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:31:20 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:31:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:31:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:32:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:32:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:32:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:33:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:33:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:33:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:34:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:34:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:34:55 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:35:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:35:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:35:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:36:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:36:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:36:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Execution time: 5100.500468254089 seconds

# %%
# Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 1.3553242683410645 seconds

# %%
# Evaluate the model
# Calculate accuracy
start_time = time.time()
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)
print("Accuracy:", accuracy)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate precision
start_time = time.time()
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)
print("Precision:", precision)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate recall
start_time = time.time()
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)
print("Recall:", recall)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate F1-score
start_time = time.time()
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)
print("F1-Score:", f1_score)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
# Out:
# 24/04/15 10:37:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Accuracy: 1.0
# Execution time: 91.8036105632782 seconds
# 24/04/15 10:38:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Precision: 1.0
# Execution time: 84.5109384059906 seconds
# 24/04/15 10:40:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Recall: 1.0
# Execution time: 84.37719297409058 seconds
# 24/04/15 10:41:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 315:==========================================>              (6 + 2) / 8]
# F1-Score: 1.0
# Execution time: 84.39763450622559 seconds
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0

# %%
from pyspark.sql.functions import expr

start_time = time.time()

# Extract Predictions and True Labels
predictions_and_labels = predictions.select("prediction", "label_tactic_indexed")

# Calculate False Positives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate True Negatives
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate False Positive Rate (FPR)
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/15 10:43:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/15 10:44:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 320:=================================================>       (7 + 1) / 8]
# False Positive Rate: 0.0
# Execution time: 185.05751013755798 seconds

# %%
spark.sparkContext.stop()
