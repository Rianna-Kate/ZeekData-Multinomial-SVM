# %%
# PySpark Imports
import pyspark
from pyspark.sql import SparkSession

# ML Classifier Imports
from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import mean, col
import time
import os
import sys

# %%
# Initialize Spark session
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.memory", "14g") \
    .config("spark.executor.memory", "14g") \
    .config("spark.executor.cores", "2") \
    .config("spark.dynamicAllocation.shuffleTracking.enabled", "true") \
    .config("spark.dynamicAllocation.enabled", "true") \
    .config("spark.dynamicAllocation.minExecutors", "2") \
    .config("spark.dynamicAllocation.maxExecutors", "2") \
    .config("spark.executor.instances", "2") \
    .config("spark.kryoserializer.buffer.max", "2047m") \
    .config("spark.sql.execution.pythonUDF.arrow.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/04/16 10:32:53 WARN Utils: Your hostname, colin-MS-7977 resolves to a loopback address: 127.0.1.1; using 192.168.0.164 instead (on interface wlx3c52a1d3ccda)
# 24/04/16 10:32:53 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/16 10:32:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
parquet_files = ["Parquet/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet", "Parquet/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet", 
                 "Parquet/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet", "Parquet/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "Parquet/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet", "Parquet/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "Parquet/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet", "Parquet/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet"]

# %%
# Read the parquet files into a dataframe
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
# Get unique labels and their counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the results
label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
start_time = time.time()

# List of labels to drop
labels_to_drop = ["Defense Evasion", "Exfiltration", "Initial Access", "Lateral Movement", "Persistence", "Privilege Escalation", "Resource Development", "Credential Access", "Reconnaissance"]

# Filter out the rows with labels to drop
df = df.filter(~col("label_tactic").isin(labels_to_drop))

# Get unique labels and their counts after filtering
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the filtered results
filtered_label_counts.show()


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# +------------+-------+
# |label_tactic|  count|
# +------------+-------+
# |   Discovery|   2086|
# |        none|9281599|
# +------------+-------+
#
# Execution time: 0.9634110927581787 seconds

# %%
start_time = time.time()



df = df.withColumn("datetime", col("datetime").cast("string"))

# Define columns to index
columns_to_index = ['service', 'conn_state', 'history', 'proto', 'dest_ip_zeek', 'community_id', 'uid', 'src_ip_zeek', 'label_tactic', 'datetime']

# Impute null values with 'null' string
for column in columns_to_index:
    df = df.fillna('null', subset=[column])

# Apply StringIndexer to each column
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").fit(df) for column in columns_to_index]

# Chain indexers together
pipeline = Pipeline(stages=indexers)

# Fit and transform the data
df_indexed = pipeline.fit(df).transform(df)

# Drop original columns
df_indexed = df_indexed.drop(*columns_to_index)

# Show the schema of the DataFrame
#df_indexed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 49.54525852203369 seconds

# %%
# Split the data into training and test sets
start_time = time.time()

train_data, test_data = df_indexed.randomSplit([0.7, 0.3], seed=42)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.0220184326171875 seconds

# %%
from pyspark.ml.feature import Imputer


start_time = time.time()

# List of numeric column names
numeric_columns = ['resp_pkts', 'orig_ip_bytes', 'missed_bytes', 'duration', 'orig_pkts',
                   'resp_ip_bytes', 'dest_port_zeek', 'orig_bytes', 'resp_bytes',
                   'src_port_zeek', 'ts']


# Create an Imputer object
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

# Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data)

# Apply the imputer to the training data
train_data_imputed = imputer_model.transform(train_data)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()


# Apply the imputer to the test data
test_data_imputed = imputer_model.transform(test_data)

# Show updated DataFrames
#train_data_imputed.show()
#test_data_imputed.show()



end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/16 10:34:04 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Execution time: 42.45440745353699 seconds
# Execution time: 0.023178577423095703 seconds

# %%
from pyspark.ml.feature import VectorAssembler


start_time = time.time()



# List of columns to assemble
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed")]

# Create the VectorAssembler
assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

# Transform the training DataFrame
train_data_assembled = assembler.transform(train_data_imputed)


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
# Transform the test DataFrame
test_data_assembled = assembler.transform(test_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Select only the features and label columns for both training and test sets
train_data_assembled = train_data_assembled.select("features", "label_tactic_indexed")
test_data_assembled = test_data_assembled.select("features", "label_tactic_indexed")

# Show the schema of the assembled training DataFrame
#train_data_assembled.printSchema()

# Show the schema of the assembled test DataFrame
#test_data_assembled.printSchema()
# Out:
# Execution time: 5.35347056388855 seconds
# Execution time: 0.07799935340881348 seconds

# %%
from pyspark.ml.feature import StandardScaler


start_time = time.time()

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/16 10:34:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:35:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 45:>                                                         (0 + 1) / 1]
# Execution time: 62.18717408180237 seconds

# %%
start_time = time.time()


# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic_indexed")


end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.03286886215209961 seconds

# %%
# Define the PCA model
pca = PCA(k=3, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/16 10:36:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:36:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:37:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:37:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:38:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:38:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:38:39 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/04/16 10:39:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 52:>                                                         (0 + 2) / 2]
# Execution time: 204.95106840133667 seconds
# 24/04/16 10:39:07 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK

# %%
# Apply PCA transformation to the training and test sets

start_time = time.time()
train_pca = pca_model.transform(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")


start_time = time.time()
test_pca = pca_model.transform(test_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.04462862014770508 seconds
# Execution time: 0.012131929397583008 seconds

# %%
# Drop the normalized column and rename the pca_features column
start_time = time.time()
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

start_time = time.time()
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Verify the changes
#train_pca.show()
#test_pca.show()
# Out:
# Execution time: 0.012164115905761719 seconds
# Execution time: 0.011611461639404297 seconds

# %%
# Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic_indexed", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)

# One Vs. Rest
ovr = OneVsRest(classifier=svm, labelCol='label_tactic_indexed')

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



# Fit the model
start_time = time.time()

svm_model = ovr.fit(train_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.016849756240844727 seconds
# 24/04/16 10:39:18 WARN DAGScheduler: Broadcasting large task binary with size 265.9 MiB
# 24/04/16 10:39:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:40:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:41:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:41:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:41:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:41:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:42:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:42:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:42:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:42:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:43:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:43:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:43:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:44:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:44:28 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:44:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:45:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:45:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:45:38 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:45:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:46:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:46:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:46:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:47:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:47:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:47:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:47:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:48:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:48:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:48:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:48:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:49:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:49:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:49:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:50:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:50:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:50:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:50:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:51:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:51:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:51:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:52:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:52:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:52:44 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:53:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:53:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:53:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:53:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:54:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:54:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:54:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:54:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:55:16 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:55:32 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:55:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:56:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:56:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:56:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:56:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:57:13 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:57:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:57:49 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:58:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:58:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:58:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:59:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:59:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:59:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 10:59:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:00:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:00:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:00:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:00:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:01:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:01:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:01:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:02:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:02:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:02:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:02:54 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:03:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:03:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:03:46 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:04:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:04:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:04:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:04:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:05:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:05:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:05:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:05:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:06:12 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:06:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:06:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:07:10 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:07:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:07:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:08:01 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:08:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:08:35 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:08:52 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:09:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:09:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:09:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:09:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:10:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:10:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:10:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:11:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:11:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:11:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:11:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:12:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:12:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:12:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:13:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:13:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:13:39 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:13:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:14:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:14:33 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:14:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:15:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:15:25 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:15:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:15:58 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:16:17 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:16:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:16:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:17:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:17:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:17:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:17:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:18:15 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:18:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:18:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:19:08 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:19:24 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:19:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:19:59 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:20:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:20:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:20:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:21:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:21:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:21:37 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:21:57 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:22:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:22:30 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:22:47 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:23:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:23:23 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:23:40 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:23:56 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:24:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:24:31 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:24:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:25:06 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:25:27 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:25:41 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:26:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:26:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:26:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:26:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:27:11 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:27:26 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:27:45 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:28:02 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:28:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:28:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:28:53 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:29:09 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:29:29 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:29:43 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:30:03 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:30:18 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:30:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:30:50 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:31:07 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:31:22 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:31:42 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 236:>                                                        (0 + 2) / 2]
# Execution time: 3159.651391506195 seconds

# %%
# Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.3237006664276123 seconds

# %%
# Evaluate the model
# Calculate accuracy
start_time = time.time()
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)
print("Accuracy:", accuracy)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate precision
start_time = time.time()
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)
print("Precision:", precision)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate recall
start_time = time.time()
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)
print("Recall:", recall)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

# Calculate F1-score
start_time = time.time()
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)
print("F1-Score:", f1_score)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")



print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
# Out:
# 24/04/16 11:32:14 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Accuracy: 0.9997616284225079
# Execution time: 82.8052294254303 seconds
# 24/04/16 11:33:36 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Precision: 0.9995233136660248
# Execution time: 74.96216177940369 seconds
# 24/04/16 11:34:51 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# Recall: 0.9997616284225079
# Execution time: 73.86248254776001 seconds
# 24/04/16 11:36:05 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 243:=================================================>       (7 + 1) / 8]
# F1-Score: 0.9996424568407074
# Execution time: 73.21276235580444 seconds
# Accuracy: 0.9997616284225079
# Precision: 0.9995233136660248
# Recall: 0.9997616284225079
# F1-Score: 0.9996424568407074

# %%
from pyspark.sql.functions import expr

start_time = time.time()

# Extract Predictions and True Labels
predictions_and_labels = predictions.select("prediction", "label_tactic_indexed")

# Calculate False Positives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate True Negatives
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic_indexed == 0)).count()

# Calculate False Positive Rate (FPR)
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/16 11:37:19 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# 24/04/16 11:38:34 WARN DAGScheduler: Broadcasting large task binary with size 266.0 MiB
# [Stage 248:=================================================>       (7 + 1) / 8]
# False Positive Rate: 0.0
# Execution time: 150.47645163536072 seconds

# %%
spark.sparkContext.stop()
