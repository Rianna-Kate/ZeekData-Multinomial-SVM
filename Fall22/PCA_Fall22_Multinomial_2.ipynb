# %%
import pyspark
from pyspark.sql import SparkSession

from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA, Imputer
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.sql.functions import mean, col, expr
import numpy as np
import time

# %%
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.maxResultSize", "3g") \
    .config("spark.driver.memory", "10g") \
    .config("spark.executor.memory", "25g") \
    .config("spark.executor.cores", "2") \
    .config("spark.executor.instances", "16") \
    .config("spark.shuffle.partitions", "180") \
    .config("spark.kryoserializer.buffer.max", "256m") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.sql.execution.arrow.enabled", "true") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/07/05 13:46:57 WARN Utils: Your hostname, colin-MS-7977 resolves to a loopback address: 127.0.1.1; using 192.168.0.164 instead (on interface wlx3c52a1d3ccda)
# 24/07/05 13:46:57 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/07/05 13:46:57 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#spark.sparkContext.stop()

# %%
parquet_files = ["Parquet/part-00000-23fdcfa3-9dd3-4c72-886c-e945bfcf92e1-c000.snappy.parquet",
                 "Parquet/part-00000-2b76f9cc-0710-45e4-9e33-98ad5808ee79-c000.snappy.parquet",
                 "Parquet/part-00000-745e350a-da9e-4619-bd52-8cc23bb41ad5-c000.snappy.parquet",
                 "Parquet/part-00000-94d13437-ae00-4a8c-9f38-edd0196cfdee-c000.snappy.parquet",
                 "Parquet/part-00000-9a46dd05-4b06-4a39-a45b-5c8460b6c37b-c000.snappy.parquet",
                 "Parquet/part-00000-9ac876be-c07d-4a18-878d-959efa26f484-c000.snappy.parquet",
                 "Parquet/part-00000-9aeb279c-81c6-4481-9b30-d35d4d194fea-c000.snappy.parquet",
                 "Parquet/part-00000-b2b625bc-5816-4586-b977-35f9ed4487fd-c000.snappy.parquet",
                 "Parquet/part-00000-be6d0798-554d-4c7a-9fef-d4c07aa0ce19-c000.snappy.parquet",
                 "Parquet/part-00000-d28b031b-bff1-4e16-853a-9b7d896627e7-c000.snappy.parquet",
                 "Parquet/part-00000-d512890f-d1e9-49d5-a136-f87f0183cb4d-c000.snappy.parquet",
                 "Parquet/part-00000-ea53b0e8-d346-44e3-9a87-1f60ac35c610-c000.snappy.parquet",
                 "Parquet/part-00000-f9afaec0-242e-41e7-906d-a42681515d75-c000.snappy.parquet"]

# %%
#Read the parquet files
df = spark.read.parquet(*parquet_files, inferSchema=True)
# Out:
# 24/07/05 13:46:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:46:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:46:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.

# %%
#Get unique label counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

label_counts.show()
# Out:
# +--------------------+------+
# |        label_tactic| count|
# +--------------------+------+
# |          Collection|     1|
# | Command and Control|    17|
# |   Credential Access|     1|
# |     Defense Evasion|  3064|
# |           Discovery| 16819|
# |           Execution|    30|
# |      Initial Access|    19|
# |    Lateral Movement|    11|
# |         Persistence|    10|
# |Privilege Escalation|  3066|
# |      Reconnaissance| 51492|
# |Resource Development|275471|
# |                none|350339|
# +--------------------+------+

# %%
start_time = time.time()

#Drop labels and get remaining counts
labels_to_drop = ['Exfiltration',
                  'Initial Access',
                  'Lateral Movement', 
                  'Persistence',
                  'Credential Access', 
                  'Collection',
                  'Command and Control',
                  'Execution']
#                 'Defense Evasion'
#                 'Discovery']
#                 'Reconnaissance',
#                 'Privilege Escalation', 
#                 'Resource Development', 

df = df.filter(~col("label_tactic").isin(labels_to_drop))
#filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

#filtered_label_counts.show()

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.03181147575378418 seconds

# %%
#Drop uid feature
df = df.drop('uid')
df = df.drop('label_technique')
df = df.drop('label_binary')

# %%
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

filtered_label_counts.show()
# Out:
# +--------------------+------+
# |        label_tactic| count|
# +--------------------+------+
# |     Defense Evasion|  3064|
# |           Discovery| 16819|
# |Privilege Escalation|  3066|
# |      Reconnaissance| 51492|
# |Resource Development|275471|
# |                none|350339|
# +--------------------+------+

# %%
df.printSchema()
# Out:
# root
#  |-- community_id: string (nullable = true)
#  |-- conn_state: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- history: string (nullable = true)
#  |-- src_ip_zeek: string (nullable = true)
#  |-- src_port_zeek: long (nullable = true)
#  |-- dest_ip_zeek: string (nullable = true)
#  |-- dest_port_zeek: long (nullable = true)
#  |-- local_orig: boolean (nullable = true)
#  |-- local_resp: boolean (nullable = true)
#  |-- missed_bytes: long (nullable = true)
#  |-- orig_bytes: long (nullable = true)
#  |-- orig_ip_bytes: long (nullable = true)
#  |-- orig_pkts: long (nullable = true)
#  |-- proto: string (nullable = true)
#  |-- resp_bytes: long (nullable = true)
#  |-- resp_ip_bytes: long (nullable = true)
#  |-- resp_pkts: long (nullable = true)
#  |-- service: string (nullable = true)
#  |-- ts: double (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- label_tactic: string (nullable = true)

# %%
start_time = time.time()

#Columns to index
columns_to_index = ['service', 
                    'conn_state', 
                    'history', 
                    'proto', 
                    'dest_ip_zeek', 
                    'community_id', 
                    'src_ip_zeek',
                    'datetime',
                    'local_resp',
                    'local_orig',
                    'label_tactic']

#Cast datetime, local_resp, local_orig to String
df = df.withColumn("datetime", col("datetime").cast("string"))
df = df.withColumn("local_resp", col("local_resp").cast("string"))
df = df.withColumn("local_orig", col("local_orig").cast("string"))

#Impute null values with empty string
for column in columns_to_index:
    df = df.fillna('', subset=[column])

# %%
#Split the into training and test sets
start_time = time.time()
train_data, test_data = df.randomSplit([0.7, 0.3], seed=42)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.025600433349609375 seconds

# %%
#StringIndexer
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").setHandleInvalid("keep") for column in columns_to_index]

#Chain indexers together
pipeline = Pipeline(stages=indexers).fit(train_data)

#Fit and transform the data
train_data_indexed = pipeline.transform(train_data)
test_data_indexed = pipeline.transform(test_data)

#Drop original columns
train_data_indexed = train_data_indexed.drop(*columns_to_index)
train_data_indexed = train_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")
test_data_indexed = test_data_indexed.drop(*columns_to_index)
test_data_indexed = test_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")

#print("train_indexed columns: ", train_data_indexed.columns)
#print("test_indexed columns: ", test_data_indexed.columns)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 19.803930044174194 seconds

# %%
start_time = time.time()

#List of numeric column names
numeric_columns = ['resp_pkts', 
                   'orig_ip_bytes', 
                   'missed_bytes', 
                   'duration', 
                   'orig_pkts',
                   'resp_ip_bytes', 
                   'dest_port_zeek', 
                   'orig_bytes', 
                   'resp_bytes',
                   'src_port_zeek', 
                   'ts']

#Create Imputer
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

#Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data_indexed)

#Apply the Imputer to the training data
train_data_imputed = imputer_model.transform(train_data_indexed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Apply the Imputer to the test data
start_time = time.time()
test_data_imputed = imputer_model.transform(test_data_indexed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

train_data_imputed = train_data_imputed.drop(*numeric_columns)
test_data_imputed = test_data_imputed.drop(*numeric_columns)

#print("\nTrain data imputed: ", train_data_imputed.columns)
#print("\n")
#print("Test data imputed: ", test_data_imputed.columns)
# Out:
# Execution time: 1.5758004188537598 seconds
# Execution time: 0.024316787719726562 seconds

# %%
start_time = time.time()

#Create VectorAssembler
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed") or column.endswith("_indexed")]
#print("Columns to assemble: ", columns_to_assemble)

assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

#Transform the training data
train_data_assembled = assembler.transform(train_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Transform the test data
start_time = time.time()
test_data_assembled = assembler.transform(test_data_imputed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Select the features and label columns
train_data_assembled = train_data_assembled.select("features", "label_tactic")
test_data_assembled = test_data_assembled.select("features", "label_tactic")

#print("Train_data_assembled columns: ", train_data_assembled.columns)
#print("Test_data_assembled columns: ", test_data_assembled.columns)
# Out:
# Execution time: 0.829270601272583 seconds
# Execution time: 0.3240327835083008 seconds

# %%
from pyspark.ml.feature import StandardScaler

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic")
# Out:
# 24/07/05 13:47:27 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/07/05 13:47:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:47:33 WARN DAGScheduler: Broadcasting large task binary with size 33.2 MiB

# %%
# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic")

# %%
# Define the PCA model
pca = PCA(k=2, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/05 13:47:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:47:36 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:47:39 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:47:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:47:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:47:46 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:47:48 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:51 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/07/05 13:47:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# [Stage 55:>                                                         (0 + 2) / 2]
# Execution time: 19.17720651626587 seconds
# 24/07/05 13:47:53 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK

# %%
# Apply PCA transformation to the training and test sets
train_pca = pca_model.transform(train_data_normalized)
test_pca = pca_model.transform(test_data_normalized)

# %%
# Drop the normalized column and rename the pca_features column
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")

# Verify the changes
#train_pca.show()
#test_pca.show()

# %%
#Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)
ovr = OneVsRest(classifier=svm, labelCol="label_tactic")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.01552128791809082 seconds

# %%
#Fit the model
start_time = time.time()
svm_model = ovr.fit(train_pca)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/05 13:47:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:47:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:01 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:01 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:01 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:04 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:04 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:04 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:04 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:04 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:04 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:04 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:04 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:48:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:48:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:23 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:23 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:23 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:23 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:23 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:23 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:23 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:23 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:49:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:49:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:53 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:53 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:53 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:53 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:53 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:50:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:50:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:51:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:52:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:53:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:54:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:55:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:25 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:25 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:25 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:25 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:25 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:25 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:25 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:25 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 13:56:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:56:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:57:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 13:58:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# ...
# 24/07/05 14:05:18 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:05:18 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:05:18 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:05:18 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:05:18 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:05:18 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:05:18 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:05:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:05:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:06:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:07:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:08:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:22 ERROR OWLQN: Failure! Resetting history: breeze.optimize.NaNHistory:
# 24/07/05 14:09:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:09:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# [Stage 863:>                                                        (0 + 2) / 2]
# Execution time: 1321.3618338108063 seconds

# %%
#Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/05 14:09:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# Execution time: 0.6630139350891113 seconds

# %%
# Evaluate the model
# Calculate accuracy
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)

# Calculate precision
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)

# Calculate recall
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)

# Calculate F1-score
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)

#Calculate FPR
evaluator_fprL = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="falsePositiveRateByLabel")
fprL_score = evaluator_fprL.evaluate(predictions)

#Calculate Weighted FPR
evaluator_fpr = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedFalsePositiveRate")
fpr_score = evaluator_fpr.evaluate(predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
print("FPR by Label:", fprL_score)
print("Weighted FPR:", fpr_score)
# Out:
# 24/07/05 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 14:10:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:00 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:16 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 14:10:17 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:17 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:17 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:17 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:17 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:17 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:17 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:18 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:29 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 14:10:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:30 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:30 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:30 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:30 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:30 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:30 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:30 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 14:10:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:52 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 14:10:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:10:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:07 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 14:11:08 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:08 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:08 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:08 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:08 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:08 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:08 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:09 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# [Stage 874:=================================================>       (7 + 1) / 8]
# Accuracy: 0.8720549145889503
# Precision: 0.7800101518628046
# Recall: 0.8720549145889505
# F1-Score: 0.8233270900077341
# FPR by Label: 0.1366820092055233
# Weighted FPR: 0.10715724663005377

# %%
start_time = time.time()

#Extract predictions and labels
predictions_and_labels = predictions.select("prediction", "label_tactic")

#Calculate false positives and true negatives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic== 0)).count()
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic == 0)).count()

#Calculate FPR
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/05 14:11:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 14:11:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# [Stage 879:==========================================>              (6 + 2) / 8]
# False Positive Rate: 0.04459557282737075
# Execution time: 20.96293044090271 seconds

# %%
from pyspark.mllib.evaluation import BinaryClassificationMetrics
from pyspark.sql import Row

# Convert DataFrame to RDD of tuples (prediction, label)
prediction_and_labels = predictions.select("prediction", "label_tactic") \
    .rdd.map(lambda row: (float(row['prediction']), float(row['label_tactic'])))


# Instantiate BinaryClassificationMetrics
metrics = BinaryClassificationMetrics(prediction_and_labels)

# Compute AUROC
auROC = metrics.areaUnderROC

# Print AUROC
print("Area under ROC = ", auROC)
# Out:
# /home/colin/.local/lib/python3.10/site-packages/pyspark/sql/context.py:158: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# 24/07/05 14:11:41 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 14:11:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:44 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 14:11:45 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# [Stage 883:=================================================>       (7 + 1) / 8]
# Area under ROC =  0.909352547493216

# %%
spark.sparkContext.stop()
