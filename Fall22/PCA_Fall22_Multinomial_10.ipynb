# %%
import pyspark
from pyspark.sql import SparkSession

from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA, Imputer
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.sql.functions import mean, col, expr
import numpy as np
import time

# %%
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.maxResultSize", "3g") \
    .config("spark.driver.memory", "10g") \
    .config("spark.executor.memory", "25g") \
    .config("spark.executor.cores", "2") \
    .config("spark.executor.instances", "16") \
    .config("spark.shuffle.partitions", "180") \
    .config("spark.kryoserializer.buffer.max", "256m") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.sql.execution.arrow.enabled", "true") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()

# %%
#spark.sparkContext.stop()

# %%
parquet_files = ["Parquet/part-00000-23fdcfa3-9dd3-4c72-886c-e945bfcf92e1-c000.snappy.parquet",
                 "Parquet/part-00000-2b76f9cc-0710-45e4-9e33-98ad5808ee79-c000.snappy.parquet",
                 "Parquet/part-00000-745e350a-da9e-4619-bd52-8cc23bb41ad5-c000.snappy.parquet",
                 "Parquet/part-00000-94d13437-ae00-4a8c-9f38-edd0196cfdee-c000.snappy.parquet",
                 "Parquet/part-00000-9a46dd05-4b06-4a39-a45b-5c8460b6c37b-c000.snappy.parquet",
                 "Parquet/part-00000-9ac876be-c07d-4a18-878d-959efa26f484-c000.snappy.parquet",
                 "Parquet/part-00000-9aeb279c-81c6-4481-9b30-d35d4d194fea-c000.snappy.parquet",
                 "Parquet/part-00000-b2b625bc-5816-4586-b977-35f9ed4487fd-c000.snappy.parquet",
                 "Parquet/part-00000-be6d0798-554d-4c7a-9fef-d4c07aa0ce19-c000.snappy.parquet",
                 "Parquet/part-00000-d28b031b-bff1-4e16-853a-9b7d896627e7-c000.snappy.parquet",
                 "Parquet/part-00000-d512890f-d1e9-49d5-a136-f87f0183cb4d-c000.snappy.parquet",
                 "Parquet/part-00000-ea53b0e8-d346-44e3-9a87-1f60ac35c610-c000.snappy.parquet",
                 "Parquet/part-00000-f9afaec0-242e-41e7-906d-a42681515d75-c000.snappy.parquet"]

# %%
#Read the parquet files
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
#Get unique label counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

label_counts.show()
# Out:
# +--------------------+------+
# |        label_tactic| count|
# +--------------------+------+
# |          Collection|     1|
# | Command and Control|    17|
# |   Credential Access|     1|
# |     Defense Evasion|  3064|
# |           Discovery| 16819|
# |           Execution|    30|
# |      Initial Access|    19|
# |    Lateral Movement|    11|
# |         Persistence|    10|
# |Privilege Escalation|  3066|
# |      Reconnaissance| 51492|
# |Resource Development|275471|
# |                none|350339|
# +--------------------+------+

# %%
start_time = time.time()

#Drop labels and get remaining counts
labels_to_drop = ['Exfiltration',
                  'Initial Access',
                  'Lateral Movement', 
                  'Persistence',
                  'Credential Access', 
                  'Collection',
                  'Command and Control',
                  'Execution']
#                 'Defense Evasion'
#                 'Discovery']
#                 'Reconnaissance',
#                 'Privilege Escalation', 
#                 'Resource Development', 

df = df.filter(~col("label_tactic").isin(labels_to_drop))
#filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

#filtered_label_counts.show()

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.02640080451965332 seconds

# %%
#Drop uid feature
df = df.drop('uid')
df = df.drop('label_technique')
df = df.drop('label_binary')

# %%
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

filtered_label_counts.show()
# Out:
# +--------------------+------+
# |        label_tactic| count|
# +--------------------+------+
# |     Defense Evasion|  3064|
# |           Discovery| 16819|
# |Privilege Escalation|  3066|
# |      Reconnaissance| 51492|
# |Resource Development|275471|
# |                none|350339|
# +--------------------+------+

# %%
df.printSchema()
# Out:
# root
#  |-- community_id: string (nullable = true)
#  |-- conn_state: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- history: string (nullable = true)
#  |-- src_ip_zeek: string (nullable = true)
#  |-- src_port_zeek: long (nullable = true)
#  |-- dest_ip_zeek: string (nullable = true)
#  |-- dest_port_zeek: long (nullable = true)
#  |-- local_orig: boolean (nullable = true)
#  |-- local_resp: boolean (nullable = true)
#  |-- missed_bytes: long (nullable = true)
#  |-- orig_bytes: long (nullable = true)
#  |-- orig_ip_bytes: long (nullable = true)
#  |-- orig_pkts: long (nullable = true)
#  |-- proto: string (nullable = true)
#  |-- resp_bytes: long (nullable = true)
#  |-- resp_ip_bytes: long (nullable = true)
#  |-- resp_pkts: long (nullable = true)
#  |-- service: string (nullable = true)
#  |-- ts: double (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- label_tactic: string (nullable = true)

# %%
start_time = time.time()

#Columns to index
columns_to_index = ['service', 
                    'conn_state', 
                    'history', 
                    'proto', 
                    'dest_ip_zeek', 
                    'community_id', 
                    'src_ip_zeek',
                    'datetime',
                    'local_resp',
                    'local_orig',
                    'label_tactic']

#Cast datetime, local_resp, local_orig to String
df = df.withColumn("datetime", col("datetime").cast("string"))
df = df.withColumn("local_resp", col("local_resp").cast("string"))
df = df.withColumn("local_orig", col("local_orig").cast("string"))

#Impute null values with empty string
for column in columns_to_index:
    df = df.fillna('', subset=[column])

# %%
#Split the into training and test sets
start_time = time.time()
train_data, test_data = df.randomSplit([0.7, 0.3], seed=42)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.02484750747680664 seconds

# %%
#StringIndexer
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").setHandleInvalid("keep") for column in columns_to_index]

#Chain indexers together
pipeline = Pipeline(stages=indexers).fit(train_data)

#Fit and transform the data
train_data_indexed = pipeline.transform(train_data)
test_data_indexed = pipeline.transform(test_data)

#Drop original columns
train_data_indexed = train_data_indexed.drop(*columns_to_index)
train_data_indexed = train_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")
test_data_indexed = test_data_indexed.drop(*columns_to_index)
test_data_indexed = test_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")

#print("train_indexed columns: ", train_data_indexed.columns)
#print("test_indexed columns: ", test_data_indexed.columns)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 18.99722719192505 seconds

# %%
start_time = time.time()

#List of numeric column names
numeric_columns = ['resp_pkts', 
                   'orig_ip_bytes', 
                   'missed_bytes', 
                   'duration', 
                   'orig_pkts',
                   'resp_ip_bytes', 
                   'dest_port_zeek', 
                   'orig_bytes', 
                   'resp_bytes',
                   'src_port_zeek', 
                   'ts']

#Create Imputer
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

#Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data_indexed)

#Apply the Imputer to the training data
train_data_imputed = imputer_model.transform(train_data_indexed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Apply the Imputer to the test data
start_time = time.time()
test_data_imputed = imputer_model.transform(test_data_indexed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

train_data_imputed = train_data_imputed.drop(*numeric_columns)
test_data_imputed = test_data_imputed.drop(*numeric_columns)

#print("\nTrain data imputed: ", train_data_imputed.columns)
#print("\n")
#print("Test data imputed: ", test_data_imputed.columns)
# Out:
# [Stage 47:==================================================>       (7 + 1) / 8]
# Execution time: 1.520186424255371 seconds
# Execution time: 0.026842594146728516 seconds

# %%
start_time = time.time()

#Create VectorAssembler
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed") or column.endswith("_indexed")]
#print("Columns to assemble: ", columns_to_assemble)

assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

#Transform the training data
train_data_assembled = assembler.transform(train_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Transform the test data
start_time = time.time()
test_data_assembled = assembler.transform(test_data_imputed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Select the features and label columns
train_data_assembled = train_data_assembled.select("features", "label_tactic")
test_data_assembled = test_data_assembled.select("features", "label_tactic")

#print("Train_data_assembled columns: ", train_data_assembled.columns)
#print("Test_data_assembled columns: ", test_data_assembled.columns)
# Out:
# Execution time: 0.7078831195831299 seconds
# Execution time: 0.3090341091156006 seconds

# %%
from pyspark.ml.feature import StandardScaler

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic")
# Out:
# 24/07/05 17:29:38 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/07/05 17:29:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:29:43 WARN DAGScheduler: Broadcasting large task binary with size 33.2 MiB

# %%
# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic")

# %%
# Define the PCA model
pca = PCA(k=10, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/05 17:29:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:29:46 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:29:48 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:29:51 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:51 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:51 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:51 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:51 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:51 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:51 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:51 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:29:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:29:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:29:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:29:59 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:00 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/07/05 17:30:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:03 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK
# Execution time: 18.709110260009766 seconds

# %%
# Apply PCA transformation to the training and test sets
train_pca = pca_model.transform(train_data_normalized)
test_pca = pca_model.transform(test_data_normalized)

# %%
# Drop the normalized column and rename the pca_features column
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")

# Verify the changes
#train_pca.show()
#test_pca.show()

# %%
#Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)
ovr = OneVsRest(classifier=svm, labelCol="label_tactic")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.018447160720825195 seconds

# %%
#Fit the model
start_time = time.time()
svm_model = ovr.fit(train_pca)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/05 17:30:04 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:12 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:12 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:12 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:12 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:12 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:12 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:12 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:12 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:15 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:15 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:15 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:15 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:15 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:15 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:15 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:16 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:30:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:30:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:37 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:37 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:37 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:37 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:37 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:37 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:37 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:37 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:31:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:31:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:32:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:02 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:02 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:02 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:02 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:02 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:03 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:03 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:03 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:06 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:06 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:06 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:06 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:06 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:06 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:06 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:06 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:33:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:33:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:28 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:28 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:32 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:32 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:32 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:32 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:34:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:34:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:35:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:29 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:32 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:33 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:33 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:33 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:33 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:33 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:33 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:33 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:36:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:36:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:37:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:36 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:36 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:36 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:36 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:36 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:36 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:36 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:36 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:40 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:38:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:38:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:39:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/05 17:40:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# Execution time: 630.0421776771545 seconds

# %%
#Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/05 17:40:33 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# Execution time: 0.8145976066589355 seconds

# %%
# Evaluate the model
# Calculate accuracy
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)

# Calculate precision
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)

# Calculate recall
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)

# Calculate F1-score
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)

#Calculate FPR
evaluator_fprL = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="falsePositiveRateByLabel")
fprL_score = evaluator_fprL.evaluate(predictions)

#Calculate Weighted FPR
evaluator_fpr = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedFalsePositiveRate")
fpr_score = evaluator_fpr.evaluate(predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
print("FPR by Label:", fprL_score)
print("Weighted FPR:", fpr_score)
# Out:
# 24/07/05 17:40:37 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 17:40:39 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:39 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:39 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:39 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:39 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:39 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:39 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:39 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:56 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 17:40:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:57 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:40:58 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:10 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 17:41:11 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:11 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:11 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:11 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:11 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:11 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:11 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:11 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:25 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 17:41:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:26 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:27 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:28 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:40 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 17:41:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:41 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:42 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:54 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 17:41:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:41:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# [Stage 455:=================================================>       (7 + 1) / 8]
# Accuracy: 0.9207006278402866
# Precision: 0.9055177304912899
# Recall: 0.9207006278402866
# F1-Score: 0.9062309365666222
# FPR by Label: 0.09405643386031619
# Weighted FPR: 0.04927272692720727

# %%
start_time = time.time()

#Extract predictions and labels
predictions_and_labels = predictions.select("prediction", "label_tactic")

#Calculate false positives and true negatives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic== 0)).count()
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic == 0)).count()

#Calculate FPR
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/05 17:42:08 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 17:42:18 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# [Stage 460:=================================================>       (7 + 1) / 8]
# False Positive Rate: 0.00047609331428960077
# Execution time: 21.099605798721313 seconds

# %%
from pyspark.mllib.evaluation import BinaryClassificationMetrics
from pyspark.sql import Row

# Convert DataFrame to RDD of tuples (prediction, label)
prediction_and_labels = predictions.select("prediction", "label_tactic") \
    .rdd.map(lambda row: (float(row['prediction']), float(row['label_tactic'])))


# Instantiate BinaryClassificationMetrics
metrics = BinaryClassificationMetrics(prediction_and_labels)

# Compute AUROC
auROC = metrics.areaUnderROC

# Print AUROC
print("Area under ROC = ", auROC)
# Out:
# /home/colin/.local/lib/python3.10/site-packages/pyspark/sql/context.py:158: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# 24/07/05 17:42:28 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 17:42:28 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:30 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:31 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:32 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/05 17:42:32 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# [Stage 464:=================================================>       (7 + 1) / 8]
# Area under ROC =  0.9353945413930346

# %%
spark.sparkContext.stop()
