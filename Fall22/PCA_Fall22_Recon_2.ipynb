# %%
import pyspark
from pyspark.sql import SparkSession

from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA, Imputer
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.sql.functions import mean, col, expr
import numpy as np
import time

# %%
spark = SparkSession.builder.appName("ce53") \
    .config("SPARK_LOCAL_IP", "192.168.1.2") \
    .master("spark://192.168.1.2:7077") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.maxResultSize", "3g") \
    .config("spark.driver.memory", "10g") \
    .config("spark.executor.memory", "25g") \
    .config("spark.executor.cores", "2") \
    .config("spark.executor.instances", "16") \
    .config("spark.shuffle.partitions", "180") \
    .config("spark.kryoserializer.buffer.max", "256m") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.sql.execution.arrow.enabled", "true") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# Warning: Ignoring non-Spark config property: SPARK_LOCAL_IP
# 24/07/28 14:06:50 WARN Utils: Your hostname, ubuntu-virtual-machine resolves to a loopback address: 127.0.1.1; using 192.168.1.106 instead (on interface ens33)
# 24/07/28 14:06:50 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/07/28 14:06:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#spark.sparkContext.stop()

# %%
parquet_files = ["hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-12 - 2021-12-19/part-00000-d512890f-d1e9-49d5-a136-f87f0183cb4d-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-19 - 2021-12-26/part-00000-d28b031b-bff1-4e16-853a-9b7d896627e7-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-26 - 2022-01-02/part-00000-94d13437-ae00-4a8c-9f38-edd0196cfdee-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-01-02 - 2022-01-09/part-00000-745e350a-da9e-4619-bd52-8cc23bb41ad5-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-08-28 - 2022-09-04/part-00000-9a46dd05-4b06-4a39-a45b-5c8460b6c37b-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-04 - 2022-09-11/part-00000-ea53b0e8-d346-44e3-9a87-1f60ac35c610-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-11 - 2022-09-18/part-00000-f9afaec0-242e-41e7-906d-a42681515d75-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-18 - 2022-09-25/part-00000-9ac876be-c07d-4a18-878d-959efa26f484-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-25 - 2022-10-02/part-00000-be6d0798-554d-4c7a-9fef-d4c07aa0ce19-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-02 - 2022-10-09/part-00000-2b76f9cc-0710-45e4-9e33-98ad5808ee79-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-09 - 2022-10-16/part-00000-b2b625bc-5816-4586-b977-35f9ed4487fd-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-16 - 2022-10-23/part-00000-9aeb279c-81c6-4481-9b30-d35d4d194fea-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-23 - 2022-10-30/part-00000-23fdcfa3-9dd3-4c72-886c-e945bfcf92e1-c000.snappy.parquet"]

# %%
#Read the parquet files
df = spark.read.parquet(*parquet_files, inferSchema=True)
# Out:
# 24/07/28 14:06:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/28 14:06:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/28 14:06:54 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.

# %%
#Get unique label counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

label_counts.show()
# Out:
# +--------------------+------+
# |        label_tactic| count|
# +--------------------+------+
# |          Collection|     1|
# | Command and Control|    17|
# |   Credential Access|     1|
# |     Defense Evasion|  3064|
# |           Discovery| 16819|
# |           Execution|    30|
# |      Initial Access|    19|
# |    Lateral Movement|    11|
# |         Persistence|    10|
# |Privilege Escalation|  3066|
# |      Reconnaissance| 51492|
# |Resource Development|275471|
# |                none|350339|
# +--------------------+------+

# %%
start_time = time.time()

#Drop labels and get remaining counts
labels_to_drop = ['Exfiltration',
                  'Initial Access',
                  'Lateral Movement', 
                  'Persistence',
                  'Privilege Escalation', 
                  'Resource Development', 
                  'Credential Access', 
                  'Defense Evasion',
                  'Collection',
                  'Command and Control',
                  'Execution',
                  'Discovery']
                  #'Reconnaissance'

df = df.filter(~col("label_tactic").isin(labels_to_drop))
#filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

#filtered_label_counts.show()

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.07415604591369629 seconds

# %%
#Drop uid feature
df = df.drop('uid')
df = df.drop('label_technique')
df = df.drop('label_binary')

# %%
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

filtered_label_counts.show()
# Out:
# +--------------+------+
# |  label_tactic| count|
# +--------------+------+
# |Reconnaissance| 51492|
# |          none|350339|
# +--------------+------+

# %%
df.printSchema()
# Out:
# root
#  |-- community_id: string (nullable = true)
#  |-- conn_state: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- history: string (nullable = true)
#  |-- src_ip_zeek: string (nullable = true)
#  |-- src_port_zeek: long (nullable = true)
#  |-- dest_ip_zeek: string (nullable = true)
#  |-- dest_port_zeek: long (nullable = true)
#  |-- local_orig: boolean (nullable = true)
#  |-- local_resp: boolean (nullable = true)
#  |-- missed_bytes: long (nullable = true)
#  |-- orig_bytes: long (nullable = true)
#  |-- orig_ip_bytes: long (nullable = true)
#  |-- orig_pkts: long (nullable = true)
#  |-- proto: string (nullable = true)
#  |-- resp_bytes: long (nullable = true)
#  |-- resp_ip_bytes: long (nullable = true)
#  |-- resp_pkts: long (nullable = true)
#  |-- service: string (nullable = true)
#  |-- ts: double (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- label_tactic: string (nullable = true)

# %%
start_time = time.time()

#Columns to index
columns_to_index = ['service', 
                    'conn_state', 
                    'history', 
                    'proto', 
                    'dest_ip_zeek', 
                    'community_id', 
                    'src_ip_zeek',
                    'datetime',
                    'local_resp',
                    'local_orig',
                    'label_tactic']

#Cast datetime, local_resp, local_orig to String
df = df.withColumn("datetime", col("datetime").cast("string"))
df = df.withColumn("local_resp", col("local_resp").cast("string"))
df = df.withColumn("local_orig", col("local_orig").cast("string"))

#Impute null values with empty string
for column in columns_to_index:
    df = df.fillna('', subset=[column])

# %%
#Split the into training and test sets
start_time = time.time()
train_data, test_data = df.randomSplit([0.7, 0.3], seed=42)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.03574562072753906 seconds

# %%
#StringIndexer
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").setHandleInvalid("keep") for column in columns_to_index]

#Chain indexers together
pipeline = Pipeline(stages=indexers).fit(train_data)

#Fit and transform the data
train_data_indexed = pipeline.transform(train_data)
test_data_indexed = pipeline.transform(test_data)

#Drop original columns
train_data_indexed = train_data_indexed.drop(*columns_to_index)
train_data_indexed = train_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")
test_data_indexed = test_data_indexed.drop(*columns_to_index)
test_data_indexed = test_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")

#print("train_indexed columns: ", train_data_indexed.columns)
#print("test_indexed columns: ", test_data_indexed.columns)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 22.32679772377014 seconds

# %%
start_time = time.time()

#List of numeric column names
numeric_columns = ['resp_pkts', 
                   'orig_ip_bytes', 
                   'missed_bytes', 
                   'duration', 
                   'orig_pkts',
                   'resp_ip_bytes', 
                   'dest_port_zeek', 
                   'orig_bytes', 
                   'resp_bytes',
                   'src_port_zeek', 
                   'ts']

#Create Imputer
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

#Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data_indexed)

#Apply the Imputer to the training data
train_data_imputed = imputer_model.transform(train_data_indexed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Apply the Imputer to the test data
start_time = time.time()
test_data_imputed = imputer_model.transform(test_data_indexed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

train_data_imputed = train_data_imputed.drop(*numeric_columns)
test_data_imputed = test_data_imputed.drop(*numeric_columns)

#print("\nTrain data imputed: ", train_data_imputed.columns)
#print("\n")
#print("Test data imputed: ", test_data_imputed.columns)
# Out:
# Execution time: 2.1276581287384033 seconds
# Execution time: 0.050687313079833984 seconds

# %%
start_time = time.time()

#Create VectorAssembler
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed") or column.endswith("_indexed")]
#print("Columns to assemble: ", columns_to_assemble)

assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

#Transform the training data
train_data_assembled = assembler.transform(train_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Transform the test data
start_time = time.time()
test_data_assembled = assembler.transform(test_data_imputed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Select the features and label columns
train_data_assembled = train_data_assembled.select("features", "label_tactic")
test_data_assembled = test_data_assembled.select("features", "label_tactic")

#print("Train_data_assembled columns: ", train_data_assembled.columns)
#print("Test_data_assembled columns: ", test_data_assembled.columns)
# Out:
# Execution time: 1.1221706867218018 seconds
# Execution time: 0.3767988681793213 seconds

# %%
from pyspark.ml.feature import StandardScaler

start_time = time.time()

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic")

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/28 14:07:35 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/07/28 14:07:36 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:07:39 WARN DAGScheduler: Broadcasting large task binary with size 20.2 MiB
# Execution time: 5.549467325210571 seconds

# %%
# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic")

# %%
# Define the PCA model
pca = PCA(k=2, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/28 14:07:42 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:07:44 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:07:46 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:07:48 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:07:50 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:07:52 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:07:55 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# [Stage 55:>                                                         (0 + 4) / 4]
# Execution time: 18.015055418014526 seconds

# %%
start_time = time.time()

# Apply PCA transformation to the training and test sets
train_pca = pca_model.transform(train_data_normalized)
test_pca = pca_model.transform(test_data_normalized)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.06246638298034668 seconds

# %%
# Drop the normalized column and rename the pca_features column
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")

# Verify the changes
#train_pca.show()
#test_pca.show()

# %%
#Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)
ovr = OneVsRest(classifier=svm, labelCol="label_tactic")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.04589414596557617 seconds

# %%
#Fit the model
start_time = time.time()
svm_model = ovr.fit(train_pca)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/28 14:07:59 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/07/28 14:08:01 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:03 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:05 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:06 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:08 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:09 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:10 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:11 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:12 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:13 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:14 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:16 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:17 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:18 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:19 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:20 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:22 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:23 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:24 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:25 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:26 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:28 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:29 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:30 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:31 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:33 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:34 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:35 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:36 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:37 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:39 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:40 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:41 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:42 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:43 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:44 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:45 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:47 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:48 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:49 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:50 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:51 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:52 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:54 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:55 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:56 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:57 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:08:58 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:00 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:01 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:02 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:03 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:04 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:05 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:06 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:08 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:08 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:10 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:11 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:12 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:13 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:14 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:15 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:16 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:17 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:19 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:20 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:21 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:22 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:23 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:24 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:25 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:26 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:27 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:28 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:30 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:31 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:32 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:33 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:34 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:35 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:37 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:38 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:39 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:40 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:41 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:42 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:44 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:45 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:46 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:47 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:48 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:49 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:50 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:51 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:52 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:53 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:55 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:56 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:57 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:58 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:09:59 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:00 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:01 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:02 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:04 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:05 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:06 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:07 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:08 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:09 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:10 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:11 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:13 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:14 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:15 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:16 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:17 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:18 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:19 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:20 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:21 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:22 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:24 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:25 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:26 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:27 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:28 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:29 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:30 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:31 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:32 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:33 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:35 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:36 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:37 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:38 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:40 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:41 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:42 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:43 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:44 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:45 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:46 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:47 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:49 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:50 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:51 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:52 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:54 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:54 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:56 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:57 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:58 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:10:59 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:00 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:01 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:02 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:03 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:04 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:05 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:07 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:08 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:09 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:10 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:11 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:12 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:13 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:14 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:15 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:16 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:18 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:19 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:20 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:21 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:22 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:23 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:24 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:25 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:26 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:27 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:29 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:30 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:31 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:32 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:33 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:34 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:35 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:36 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:37 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:38 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:39 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:40 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:42 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:42 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:44 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:45 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:46 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:47 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:48 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:49 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:50 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:51 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:52 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:53 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:54 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:55 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:56 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:57 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:11:59 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:00 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:01 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:02 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:03 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:04 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:05 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:06 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:07 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:08 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:09 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:10 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:11 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:12 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:14 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:15 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:16 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:17 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:18 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:19 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:20 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:21 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:22 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:23 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:24 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:25 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:26 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:27 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:28 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:29 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:30 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:31 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:32 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:33 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:34 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:35 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:37 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:37 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:39 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:40 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:41 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:42 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:43 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:44 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:45 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:46 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:47 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:48 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:49 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:50 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:52 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:54 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:55 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:56 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:57 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:58 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:12:59 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:00 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:01 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:02 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:03 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:05 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:05 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:07 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:08 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:09 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:10 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:11 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:12 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:13 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:14 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:15 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:16 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:17 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:18 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:19 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:20 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:21 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:23 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# Execution time: 325.0179307460785 seconds

# %%
#Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/28 14:13:23 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# Execution time: 0.29683804512023926 seconds

# %%
# Evaluate the model
# Calculate accuracy
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)

# Calculate precision
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)

# Calculate recall
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)

# Calculate F1-score
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)

#Calculate FPR
evaluator_fprL = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="falsePositiveRateByLabel")
fprL_score = evaluator_fprL.evaluate(predictions)

#Calculate Weighted FPR
evaluator_fpr = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedFalsePositiveRate")
fpr_score = evaluator_fpr.evaluate(predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
print("FPR by Label:", fprL_score)
print("Weighted FPR:", fpr_score)
# Out:
# 24/07/28 14:13:25 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:30 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:34 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:38 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:42 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:45 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# [Stage 358:===================================================>   (15 + 1) / 16]
# Accuracy: 0.8721492284437653
# Precision: 0.7606442766750551
# Recall: 0.8721492284437653
# F1-Score: 0.8125893653331736
# FPR by Label: 1.0
# Weighted FPR: 0.8721492284437653

# %%
start_time = time.time()

#Extract predictions and labels
predictions_and_labels = predictions.select("prediction", "label_tactic")

#Calculate false positives and true negatives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic== 0)).count()
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic == 0)).count()

#Calculate FPR
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/28 14:13:49 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:53 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# [Stage 363:================================================>      (14 + 2) / 16]
# False Positive Rate: 0.0
# Execution time: 7.882845878601074 seconds

# %%
from pyspark.mllib.evaluation import BinaryClassificationMetrics
from pyspark.sql import Row

# Convert DataFrame to RDD of tuples (prediction, label)
prediction_and_labels = predictions.select("prediction", "label_tactic") \
    .rdd.map(lambda row: (float(row['prediction']), float(row['label_tactic'])))


# Instantiate BinaryClassificationMetrics
metrics = BinaryClassificationMetrics(prediction_and_labels)

# Compute AUROC
auROC = metrics.areaUnderROC

# Print AUROC
print("Area under ROC = ", auROC)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/pyspark/sql/context.py:158: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# 24/07/28 14:13:57 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# 24/07/28 14:13:59 WARN DAGScheduler: Broadcasting large task binary with size 20.3 MiB
# Area under ROC =  0.5

# %%
spark.sparkContext.stop()
