# %%
import pyspark
from pyspark.sql import SparkSession

from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA, Imputer
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.sql.functions import mean, col, expr
import numpy as np
import time

# %%
spark = SparkSession.builder.appName("rka7 - Fall22 PCA Multi(2)") \
    .master("spark://192.168.1.2:7077") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.maxResultSize", "3g") \
    .config("spark.driver.memory", "10g") \
    .config("spark.executor.memory", "25g") \
    .config("spark.executor.cores", "2") \
    .config("spark.executor.instances", "16") \
    .config("spark.shuffle.partitions", "200") \
    .config("spark.kryoserializer.buffer.max", "256m") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/07/16 18:49:46 WARN Utils: Your hostname, ubuntu-virtual-machine resolves to a loopback address: 127.0.1.1; using 192.168.1.107 instead (on interface ens33)
# 24/07/16 18:49:46 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/07/16 18:49:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#spark.sparkContext.stop()

# %%
parquet_files = ["hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-12 - 2021-12-19/part-00000-d512890f-d1e9-49d5-a136-f87f0183cb4d-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-19 - 2021-12-26/part-00000-d28b031b-bff1-4e16-853a-9b7d896627e7-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-26 - 2022-01-02/part-00000-94d13437-ae00-4a8c-9f38-edd0196cfdee-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-01-02 - 2022-01-09/part-00000-745e350a-da9e-4619-bd52-8cc23bb41ad5-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-08-28 - 2022-09-04/part-00000-9a46dd05-4b06-4a39-a45b-5c8460b6c37b-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-04 - 2022-09-11/part-00000-ea53b0e8-d346-44e3-9a87-1f60ac35c610-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-11 - 2022-09-18/part-00000-f9afaec0-242e-41e7-906d-a42681515d75-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-18 - 2022-09-25/part-00000-9ac876be-c07d-4a18-878d-959efa26f484-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-25 - 2022-10-02/part-00000-be6d0798-554d-4c7a-9fef-d4c07aa0ce19-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-02 - 2022-10-09/part-00000-2b76f9cc-0710-45e4-9e33-98ad5808ee79-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-09 - 2022-10-16/part-00000-b2b625bc-5816-4586-b977-35f9ed4487fd-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-16 - 2022-10-23/part-00000-9aeb279c-81c6-4481-9b30-d35d4d194fea-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-23 - 2022-10-30/part-00000-23fdcfa3-9dd3-4c72-886c-e945bfcf92e1-c000.snappy.parquet"]

# %%
#Read the parquet files
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
#Get unique label counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

label_counts.show()
# Out:
# +--------------------+------+
# |        label_tactic| count|
# +--------------------+------+
# |          Collection|     1|
# | Command and Control|    17|
# |   Credential Access|     1|
# |     Defense Evasion|  3064|
# |           Discovery| 16819|
# |           Execution|    30|
# |      Initial Access|    19|
# |    Lateral Movement|    11|
# |         Persistence|    10|
# |Privilege Escalation|  3066|
# |      Reconnaissance| 51492|
# |Resource Development|275471|
# |                none|350339|
# +--------------------+------+

# %%
start_time = time.time()

#Drop labels and get remaining counts
labels_to_drop = ['Exfiltration',
                  'Initial Access',
                  'Lateral Movement', 
                  'Persistence',
                  'Credential Access', 
                  'Collection',
                  'Command and Control',
                  'Execution']
#                 'Defense Evasion'
#                 'Discovery']
#                 'Reconnaissance',
#                 'Privilege Escalation', 
#                 'Resource Development', 

df = df.filter(~col("label_tactic").isin(labels_to_drop))
#filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

#filtered_label_counts.show()

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.038877010345458984 seconds

# %%
#Drop uid feature
df = df.drop('uid')
df = df.drop('label_technique')
df = df.drop('label_binary')

# %%
#filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")
#filtered_label_counts.show()

# %%
#df.printSchema()

# %%
start_time = time.time()

#Columns to index
columns_to_index = ['service', 
                    'conn_state', 
                    'history', 
                    'proto', 
                    'dest_ip_zeek', 
                    'community_id', 
                    'src_ip_zeek',
                    'datetime',
                    'local_resp',
                    'local_orig',
                    'label_tactic']

#Cast datetime, local_resp, local_orig to String
df = df.withColumn("datetime", col("datetime").cast("string"))
df = df.withColumn("local_resp", col("local_resp").cast("string"))
df = df.withColumn("local_orig", col("local_orig").cast("string"))

#Impute null values with empty string
for column in columns_to_index:
    df = df.fillna('', subset=[column])

# %%
#Split the into training and test sets
start_time = time.time()
train_data, test_data = df.randomSplit([0.7, 0.3], seed=42)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.020273447036743164 seconds

# %%
#StringIndexer
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").setHandleInvalid("keep") for column in columns_to_index]

#Chain indexers together
pipeline = Pipeline(stages=indexers).fit(train_data)

#Fit and transform the data
train_data_indexed = pipeline.transform(train_data)
test_data_indexed = pipeline.transform(test_data)

#Drop original columns
train_data_indexed = train_data_indexed.drop(*columns_to_index)
train_data_indexed = train_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")
test_data_indexed = test_data_indexed.drop(*columns_to_index)
test_data_indexed = test_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 39.052730321884155 seconds

# %%
start_time = time.time()

#List of numeric column names
numeric_columns = ['resp_pkts', 
                   'orig_ip_bytes', 
                   'missed_bytes', 
                   'duration', 
                   'orig_pkts',
                   'resp_ip_bytes', 
                   'dest_port_zeek', 
                   'orig_bytes', 
                   'resp_bytes',
                   'src_port_zeek', 
                   'ts']

#Create Imputer
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

#Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data_indexed)

#Apply the Imputer to the training data
train_data_imputed = imputer_model.transform(train_data_indexed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Apply the Imputer to the test data
start_time = time.time()
test_data_imputed = imputer_model.transform(test_data_indexed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

train_data_imputed = train_data_imputed.drop(*numeric_columns)
test_data_imputed = test_data_imputed.drop(*numeric_columns)

#print("\nTrain data imputed: ", train_data_imputed.columns)
#print("\n")
#print("Test data imputed: ", test_data_imputed.columns)
# Out:
# Execution time: 3.0338735580444336 seconds
# Execution time: 0.01690053939819336 seconds

# %%
start_time = time.time()

#Create VectorAssembler
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed") or column.endswith("_indexed")]
#print("Columns to assemble: ", columns_to_assemble)

assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

#Transform the training data
train_data_assembled = assembler.transform(train_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Transform the test data
start_time = time.time()
test_data_assembled = assembler.transform(test_data_imputed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Select the features and label columns
train_data_assembled = train_data_assembled.select("features", "label_tactic")
test_data_assembled = test_data_assembled.select("features", "label_tactic")

#print("Train_data_assembled columns: ", train_data_assembled.columns)
#print("Test_data_assembled columns: ", test_data_assembled.columns)
# Out:
# Execution time: 1.3807461261749268 seconds
# Execution time: 0.5483055114746094 seconds

# %%
from pyspark.ml.feature import StandardScaler
start_time = time.time()

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic")

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/16 18:50:45 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/07/16 18:50:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/16 18:50:52 WARN DAGScheduler: Broadcasting large task binary with size 33.2 MiB
# [Stage 46:>                                                         (0 + 1) / 1]
# Execution time: 8.542289972305298 seconds

# %%
# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic")

# %%
# Define the PCA model
pca = PCA(k=2, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/15 12:59:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 12:59:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# Execution time: 28.943777084350586 seconds

# %%
# Apply PCA transformation to the training and test sets
train_pca = pca_model.transform(train_data_normalized)
test_pca = pca_model.transform(test_data_normalized)

# %%
# Drop the normalized column and rename the pca_features column
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")

# Verify the changes
#train_pca.show()
#test_pca.show()

# %%
#Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)
ovr = OneVsRest(classifier=svm, labelCol="label_tactic")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.044777870178222656 seconds

# %%
#Fit the model
start_time = time.time()
svm_model = ovr.fit(train_pca)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/15 13:00:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:00:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:01:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:02:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13
WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:22:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:23:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:24:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:25:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:26:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:27:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# Execution time: 1630.5799157619476 seconds

# %%
#Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.958681583404541 seconds

# %%
# Evaluate the model
# Calculate accuracy
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)

# Calculate precision
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)

# Calculate recall
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)

# Calculate F1-score
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)

#Calculate FPR
evaluator_fprL = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="falsePositiveRateByLabel")
fprL_score = evaluator_fprL.evaluate(predictions)

#Calculate Weighted FPR
evaluator_fpr = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedFalsePositiveRate")
fpr_score = evaluator_fpr.evaluate(predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
print("FPR by Label:", fprL_score)
print("Weighted FPR:", fpr_score)
# Out:
# 24/07/15 13:27:39 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:27:52 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:28:04 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:28:13 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:28:23 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:28:32 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# [Stage 786:====================================================>  (20 + 1) / 21]
# Accuracy: 0.8783496303362748
# Precision: 0.7849418079957753
# Recall: 0.8783496303362748
# F1-Score: 0.8288746428683815
# FPR by Label: 0.12290150690425715
# Weighted FPR: 0.10047733735681563

# %%
start_time = time.time()

#Extract predictions and labels
predictions_and_labels = predictions.select("prediction", "label_tactic")

#Calculate false positives and true negatives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic== 0)).count()
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic == 0)).count()

#Calculate FPR
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/15 13:28:43 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:28:52 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# [Stage 791:====================================================>  (20 + 1) / 21]
# False Positive Rate: 0.029859992565976955
# Execution time: 18.24327826499939 seconds

# %%
from pyspark.mllib.evaluation import BinaryClassificationMetrics
from pyspark.sql import Row

# Convert DataFrame to RDD of tuples (prediction, label)
prediction_and_labels = predictions.select("prediction", "label_tactic") \
    .rdd.map(lambda row: (float(row['prediction']), float(row['label_tactic'])))


# Instantiate BinaryClassificationMetrics
metrics = BinaryClassificationMetrics(prediction_and_labels)

# Compute AUROC
auROC = metrics.areaUnderROC

# Print AUROC
print("Area under ROC = ", auROC)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/pyspark/sql/context.py:158: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# 24/07/15 13:29:01 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:29:06 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# Area under ROC =  0.9235400315970563

# %%
spark.sparkContext.stop()
