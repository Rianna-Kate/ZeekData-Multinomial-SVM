# %%
import pyspark
from pyspark.sql import SparkSession

from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA, Imputer
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.sql.functions import mean, col, expr
import numpy as np
import time

# %%
spark = SparkSession.builder.appName("rka7 - Fall22 PCA Multi(3)") \
    .master("spark://192.168.1.2:7077") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.maxResultSize", "3g") \
    .config("spark.driver.memory", "10g") \
    .config("spark.executor.memory", "25g") \
    .config("spark.executor.cores", "2") \
    .config("spark.executor.instances", "16") \
    .config("spark.shuffle.partitions", "200") \
    .config("spark.kryoserializer.buffer.max", "256m") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/07/16 18:53:44 WARN Utils: Your hostname, ubuntu-virtual-machine resolves to a loopback address: 127.0.1.1; using 192.168.1.107 instead (on interface ens33)
# 24/07/16 18:53:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/07/16 18:53:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#spark.sparkContext.stop()

# %%
parquet_files = ["hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-12 - 2021-12-19/part-00000-d512890f-d1e9-49d5-a136-f87f0183cb4d-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-19 - 2021-12-26/part-00000-d28b031b-bff1-4e16-853a-9b7d896627e7-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-26 - 2022-01-02/part-00000-94d13437-ae00-4a8c-9f38-edd0196cfdee-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-01-02 - 2022-01-09/part-00000-745e350a-da9e-4619-bd52-8cc23bb41ad5-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-08-28 - 2022-09-04/part-00000-9a46dd05-4b06-4a39-a45b-5c8460b6c37b-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-04 - 2022-09-11/part-00000-ea53b0e8-d346-44e3-9a87-1f60ac35c610-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-11 - 2022-09-18/part-00000-f9afaec0-242e-41e7-906d-a42681515d75-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-18 - 2022-09-25/part-00000-9ac876be-c07d-4a18-878d-959efa26f484-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-25 - 2022-10-02/part-00000-be6d0798-554d-4c7a-9fef-d4c07aa0ce19-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-02 - 2022-10-09/part-00000-2b76f9cc-0710-45e4-9e33-98ad5808ee79-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-09 - 2022-10-16/part-00000-b2b625bc-5816-4586-b977-35f9ed4487fd-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-16 - 2022-10-23/part-00000-9aeb279c-81c6-4481-9b30-d35d4d194fea-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-23 - 2022-10-30/part-00000-23fdcfa3-9dd3-4c72-886c-e945bfcf92e1-c000.snappy.parquet"]

# %%
#Read the parquet files
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
#Get unique label counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

label_counts.show()
# Out:
# +--------------------+------+
# |        label_tactic| count|
# +--------------------+------+
# |          Collection|     1|
# | Command and Control|    17|
# |   Credential Access|     1|
# |     Defense Evasion|  3064|
# |           Discovery| 16819|
# |           Execution|    30|
# |      Initial Access|    19|
# |    Lateral Movement|    11|
# |         Persistence|    10|
# |Privilege Escalation|  3066|
# |      Reconnaissance| 51492|
# |Resource Development|275471|
# |                none|350339|
# +--------------------+------+

# %%
start_time = time.time()

#Drop labels and get remaining counts
labels_to_drop = ['Exfiltration',
                  'Initial Access',
                  'Lateral Movement', 
                  'Persistence',
                  'Credential Access', 
                  'Collection',
                  'Command and Control',
                  'Execution']
#                 'Defense Evasion'
#                 'Discovery']
#                 'Reconnaissance',
#                 'Privilege Escalation', 
#                 'Resource Development', 

df = df.filter(~col("label_tactic").isin(labels_to_drop))
#filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

#filtered_label_counts.show()

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.06763315200805664 seconds

# %%
#Drop uid feature
df = df.drop('uid')
df = df.drop('label_technique')
df = df.drop('label_binary')

# %%
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

filtered_label_counts.show()
# Out:
# [Stage 4:===================================================>     (19 + 2) / 21]
# +--------------------+------+
# |        label_tactic| count|
# +--------------------+------+
# |     Defense Evasion|  3064|
# |           Discovery| 16819|
# |Privilege Escalation|  3066|
# |      Reconnaissance| 51492|
# |Resource Development|275471|
# |                none|350339|
# +--------------------+------+

# %%
df.printSchema()
# Out:
# root
#  |-- community_id: string (nullable = true)
#  |-- conn_state: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- history: string (nullable = true)
#  |-- src_ip_zeek: string (nullable = true)
#  |-- src_port_zeek: long (nullable = true)
#  |-- dest_ip_zeek: string (nullable = true)
#  |-- dest_port_zeek: long (nullable = true)
#  |-- local_orig: boolean (nullable = true)
#  |-- local_resp: boolean (nullable = true)
#  |-- missed_bytes: long (nullable = true)
#  |-- orig_bytes: long (nullable = true)
#  |-- orig_ip_bytes: long (nullable = true)
#  |-- orig_pkts: long (nullable = true)
#  |-- proto: string (nullable = true)
#  |-- resp_bytes: long (nullable = true)
#  |-- resp_ip_bytes: long (nullable = true)
#  |-- resp_pkts: long (nullable = true)
#  |-- service: string (nullable = true)
#  |-- ts: double (nullable = true)
#  |-- datetime: timestamp (nullable = true)
#  |-- label_tactic: string (nullable = true)

# %%
start_time = time.time()

#Columns to index
columns_to_index = ['service', 
                    'conn_state', 
                    'history', 
                    'proto', 
                    'dest_ip_zeek', 
                    'community_id', 
                    'src_ip_zeek',
                    'datetime',
                    'local_resp',
                    'local_orig',
                    'label_tactic']

#Cast datetime, local_resp, local_orig to String
df = df.withColumn("datetime", col("datetime").cast("string"))
df = df.withColumn("local_resp", col("local_resp").cast("string"))
df = df.withColumn("local_orig", col("local_orig").cast("string"))

#Impute null values with empty string
for column in columns_to_index:
    df = df.fillna('', subset=[column])

# %%
#Split the into training and test sets
start_time = time.time()
train_data, test_data = df.randomSplit([0.7, 0.3], seed=42)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.025610923767089844 seconds

# %%
#StringIndexer
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").setHandleInvalid("keep") for column in columns_to_index]

#Chain indexers together
pipeline = Pipeline(stages=indexers).fit(train_data)

#Fit and transform the data
train_data_indexed = pipeline.transform(train_data)
test_data_indexed = pipeline.transform(test_data)

#Drop original columns
train_data_indexed = train_data_indexed.drop(*columns_to_index)
train_data_indexed = train_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")
test_data_indexed = test_data_indexed.drop(*columns_to_index)
test_data_indexed = test_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")

#print("train_indexed columns: ", train_data_indexed.columns)
#print("test_indexed columns: ", test_data_indexed.columns)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 37.43239903450012 seconds

# %%
start_time = time.time()

#List of numeric column names
numeric_columns = ['resp_pkts', 
                   'orig_ip_bytes', 
                   'missed_bytes', 
                   'duration', 
                   'orig_pkts',
                   'resp_ip_bytes', 
                   'dest_port_zeek', 
                   'orig_bytes', 
                   'resp_bytes',
                   'src_port_zeek', 
                   'ts']

#Create Imputer
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

#Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data_indexed)

#Apply the Imputer to the training data
train_data_imputed = imputer_model.transform(train_data_indexed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Apply the Imputer to the test data
start_time = time.time()
test_data_imputed = imputer_model.transform(test_data_indexed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

train_data_imputed = train_data_imputed.drop(*numeric_columns)
test_data_imputed = test_data_imputed.drop(*numeric_columns)

#print("\nTrain data imputed: ", train_data_imputed.columns)
#print("\n")
#print("Test data imputed: ", test_data_imputed.columns)
# Out:
# Execution time: 3.163851737976074 seconds
# Execution time: 0.029597759246826172 seconds

# %%
start_time = time.time()

#Create VectorAssembler
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed") or column.endswith("_indexed")]
#print("Columns to assemble: ", columns_to_assemble)

assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

#Transform the training data
train_data_assembled = assembler.transform(train_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Transform the test data
start_time = time.time()
test_data_assembled = assembler.transform(test_data_imputed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Select the features and label columns
train_data_assembled = train_data_assembled.select("features", "label_tactic")
test_data_assembled = test_data_assembled.select("features", "label_tactic")

#print("Train_data_assembled columns: ", train_data_assembled.columns)
#print("Test_data_assembled columns: ", test_data_assembled.columns)
# Out:
# Execution time: 1.170217514038086 seconds
# Execution time: 0.4315199851989746 seconds

# %%
from pyspark.ml.feature import StandardScaler
start_time = time.time()

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic")

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/16 18:54:48 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/07/16 18:54:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/16 18:54:55 WARN DAGScheduler: Broadcasting large task binary with size 33.2 MiB
# [Stage 49:>                                                         (0 + 1) / 1]
# Execution time: 8.798804759979248 seconds

# %%
# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic")

# %%
# Define the PCA model
pca = PCA(k=3, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/15 13:42:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:42:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:42:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:42:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:42:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:42:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:42:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# [Stage 56:>                                                         (0 + 4) / 4]
# Execution time: 28.563889741897583 seconds

# %%
# Apply PCA transformation to the training and test sets
train_pca = pca_model.transform(train_data_normalized)
test_pca = pca_model.transform(test_data_normalized)

# %%
# Drop the normalized column and rename the pca_features column
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")

# Verify the changes
#train_pca.show()
#test_pca.show()

# %%
#Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)
ovr = OneVsRest(classifier=svm, labelCol="label_tactic")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.05037379264831543 seconds

# %%
#Fit the model
start_time = time.time()
svm_model = ovr.fit(train_pca)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/15 13:42:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:42:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:42:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:43:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:44:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:45:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:46:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:47:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:48:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:49:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:50:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:36 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:51:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:52:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:53:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:54:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:09 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:11 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:54 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:56 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:55:58 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:00 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:05 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:29 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:33 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:40 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:52 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:56:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:03 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:07 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:14 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:16 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:18 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:20 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:22 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:25 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:27 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:32 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:38 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:43 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:45 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:47 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:49 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:51 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:53 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:55 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:57 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:57:59 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:01 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:02 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:04 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:06 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:08 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:10 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:12 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:13 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:15 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:17 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:19 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:21 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:23 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:24 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:26 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:28 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:30 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:31 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:34 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:35 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:37 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:39 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:41 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:42 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:44 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:46 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:48 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# 24/07/15 13:58:50 WARN DAGScheduler: Broadcasting large task binary with size 33.3 MiB
# Execution time: 965.0199353694916 seconds

# %%
#Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.7591066360473633 seconds

# %%
# Evaluate the model
# Calculate accuracy
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)

# Calculate precision
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)

# Calculate recall
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)

# Calculate F1-score
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)

#Calculate FPR
evaluator_fprL = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="falsePositiveRateByLabel")
fprL_score = evaluator_fprL.evaluate(predictions)

#Calculate Weighted FPR
evaluator_fpr = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedFalsePositiveRate")
fpr_score = evaluator_fpr.evaluate(predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
print("FPR by Label:", fprL_score)
print("Weighted FPR:", fpr_score)
# Out:
# 24/07/15 13:58:57 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:59:09 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:59:19 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:59:30 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:59:40 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 13:59:50 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# [Stage 573:====================================================>  (20 + 1) / 21]
# Accuracy: 0.9010827569759122
# Precision: 0.8427793491234427
# Recall: 0.9010827569759123
# F1-Score: 0.8681594861840274
# FPR by Label: 0.1373498347944002
# Weighted FPR: 0.07384628578201918

# %%
start_time = time.time()

#Extract predictions and labels
predictions_and_labels = predictions.select("prediction", "label_tactic")

#Calculate false positives and true negatives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic== 0)).count()
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic == 0)).count()

#Calculate FPR
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/07/15 13:59:58 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 14:00:08 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# [Stage 578:====================================================>  (20 + 1) / 21]
# False Positive Rate: 0.00517806912527618
# Execution time: 18.453903436660767 seconds

# %%
from pyspark.mllib.evaluation import BinaryClassificationMetrics
from pyspark.sql import Row

# Convert DataFrame to RDD of tuples (prediction, label)
prediction_and_labels = predictions.select("prediction", "label_tactic") \
    .rdd.map(lambda row: (float(row['prediction']), float(row['label_tactic'])))


# Instantiate BinaryClassificationMetrics
metrics = BinaryClassificationMetrics(prediction_and_labels)

# Compute AUROC
auROC = metrics.areaUnderROC

# Print AUROC
print("Area under ROC = ", auROC)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/pyspark/sql/context.py:158: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# 24/07/15 14:00:17 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# 24/07/15 14:00:21 WARN DAGScheduler: Broadcasting large task binary with size 33.4 MiB
# Area under ROC =  0.9105875596726463

# %%
spark.sparkContext.stop()
