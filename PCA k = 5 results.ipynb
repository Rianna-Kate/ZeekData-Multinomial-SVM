# %%
# PySpark Imports
import pyspark
from pyspark.sql import SparkSession

# ML Classifier Imports
from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import mean, col
import time
import os
import sys

# %%
# Initialize Spark session
spark = SparkSession.builder.appName("ce53") \
    .master("local[*]") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.memory", "14g") \
    .config("spark.executor.memory", "14g") \
    .config("spark.executor.cores", "2") \
    .config("spark.dynamicAllocation.shuffleTracking.enabled", "true") \
    .config("spark.dynamicAllocation.enabled", "true") \
    .config("spark.dynamicAllocation.minExecutors", "2") \
    .config("spark.dynamicAllocation.maxExecutors", "2") \
    .config("spark.executor.instances", "2") \
    .config("spark.kryoserializer.buffer.max", "2047m") \
    .config("spark.sql.execution.pythonUDF.arrow.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# 24/04/06 19:12:22 WARN Utils: Your hostname, colin-MS-7977 resolves to a loopback address: 127.0.1.1; using 192.168.0.164 instead (on interface wlx3c52a1d3ccda)
# 24/04/06 19:12:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/06 19:12:22 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
parquet_files = ["Parquet/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet", "Parquet/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet", 
                 "Parquet/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet", "Parquet/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "Parquet/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet", "Parquet/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "Parquet/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet", "Parquet/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet"]

# %%
# Read the parquet files into a dataframe
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
# Get unique labels and their counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the results
label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
# List of labels to drop
labels_to_drop = ["Defense Evasion", "Exfiltration", "Initial Access", "Lateral Movement", "Persistence", "Privilege Escalation", "Resource Development", "Credential Access"]

# Filter out the rows with labels to drop
df = df.filter(~col("label_tactic").isin(labels_to_drop))

# Get unique labels and their counts after filtering
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

# Show the filtered results
filtered_label_counts.show()
# Out:
# [Stage 4:===================================================>       (7 + 1) / 8]
# +--------------+-------+
# |  label_tactic|  count|
# +--------------+-------+
# |     Discovery|   2086|
# |Reconnaissance|9278722|
# |          none|9281599|
# +--------------+-------+

# %%
# Drop the datetime column
#df = df.drop("datetime")
df = df.withColumn("datetime", col("datetime").cast("string"))

# Define columns to index
columns_to_index = ['service', 'conn_state', 'history', 'proto', 'dest_ip_zeek', 'community_id', 'uid', 'src_ip_zeek', 'label_tactic', 'datetime']

# Impute null values with 'null' string
for column in columns_to_index:
    df = df.fillna('null', subset=[column])

# Apply StringIndexer to each column
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").fit(df) for column in columns_to_index]

# Chain indexers together
pipeline = Pipeline(stages=indexers)

# Fit and transform the data
df_indexed = pipeline.fit(df).transform(df)

# Drop original columns
df_indexed = df_indexed.drop(*columns_to_index)

# Show the schema of the DataFrame
df_indexed.show()
# Out:
# 24/04/07 01:20:49 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB
# [Stage 37:>                                                         (0 + 1) / 1]
# +---------+-------------+----------+------------+--------------------+---------+-------------+--------------+----------+----------+----------+-------------+-------------------+---------------+------------------+---------------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+----------------+
# |resp_pkts|orig_ip_bytes|local_resp|missed_bytes|            duration|orig_pkts|resp_ip_bytes|dest_port_zeek|orig_bytes|local_orig|resp_bytes|src_port_zeek|                 ts|service_indexed|conn_state_indexed|history_indexed|proto_indexed|dest_ip_zeek_indexed|community_id_indexed|uid_indexed|src_ip_zeek_indexed|label_tactic_indexed|datetime_indexed|
# +---------+-------------+----------+------------+--------------------+---------+-------------+--------------+----------+----------+----------+-------------+-------------------+---------------+------------------+---------------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+----------------+
# |        1|           68|     false|           0|1.599788665771484...|        1|           68|            53|        40|     false|        40|        50415|1.641459589613973E9|            0.0|               2.0|            3.0|          0.0|                13.0|            262356.0|  4286424.0|               10.0|                 0.0|        574381.0|
# |        0|           28|     false|           0|                NULL|        1|            0|         21868|      NULL|     false|      NULL|        35104|1.641459539619677E9|            1.0|               0.0|            0.0|          0.0|                19.0|            303514.0|  1816248.0|                2.0|                 0.0|       1040243.0|
# |        0|          116|     false|           0|                NULL|        1|            0|           547|      NULL|     false|      NULL|          546|1.641459540445189E9|            1.0|               0.0|            0.0|          0.0|                11.0|                 0.0|  1230077.0|               12.0|                 0.0|       1040245.0|
# |        0|           28|     false|           0|                NULL|        1|            0|         21358|      NULL|     false|      NULL|        35105|1.641459540615094E9|            1.0|               0.0|            0.0|          0.0|                 5.0|            211983.0|  4365094.0|                2.0|                 0.0|       1040246.0|
# |        0|           28|     false|           0|                NULL|        1|            0|         21803|      NULL|     false|      NULL|        35104|1.641459540420607E9|            1.0|               0.0|            0.0|          0.0|                19.0|            258882.0|  2825551.0|                2.0|                 0.0|       1040244.0|
# |        0|          100|     false|           0|                NULL|        1|            0|          1044|      NULL|     false|      NULL|        35104|1.641459541221198E9|            1.0|               0.0|            0.0|          0.0|                19.0|            380000.0|  1406078.0|                2.0|                 0.0|       1040247.0|
# |        0|           28|     false|           0|                NULL|        1|            0|         21358|      NULL|     false|      NULL|        35106|1.641459541615545E9|            1.0|               0.0|            0.0|          0.0|                 5.0|            383438.0|   944989.0|                2.0|                 0.0|       1040248.0|
# |        0|          100|     false|           0|                NULL|        1|            0|          1044|      NULL|     false|      NULL|        35105|1.641459542021624E9|            1.0|               0.0|            0.0|          0.0|                19.0|            364179.0|  4276713.0|                2.0|                 0.0|       1040249.0|
# |        0|          114|     false|           0|6.198883056640625E-5|        2|            0|            53|        58|     false|         0|        40516|1.641459592673273E9|            0.0|               0.0|            0.0|          0.0|                 8.0|             72448.0|  3234827.0|                2.0|                 0.0|        574382.0|
# |        0|          114|     false|           0|1.788139343261718...|        2|            0|            53|        58|     false|         0|        50407|1.641459592673361E9|            0.0|               0.0|            0.0|          0.0|                 8.0|            133161.0|  4121958.0|                2.0|                 0.0|        574382.0|
# |        0|           76|     false|           0|                NULL|        1|            0|           123|      NULL|     false|      NULL|        35193| 1.64145954261617E9|            4.0|               0.0|            0.0|          0.0|                 5.0|            390640.0|  1658135.0|                2.0|                 0.0|       1040251.0|
# |        0|           68|     false|           0|                NULL|        1|            0|         34578|      NULL|     false|      NULL|        35104|1.641459542821879E9|            1.0|               0.0|            0.0|          0.0|                19.0|            290603.0|  2689409.0|                2.0|                 0.0|       1040252.0|
# |        0|           28|     false|           0|                NULL|        1|            0|         16974|      NULL|     false|      NULL|        35104|1.641459543616761E9|            1.0|               0.0|            0.0|          0.0|                 5.0|            254732.0|  2782850.0|                2.0|                 0.0|       1040253.0|
# |        0|           68|     false|           0|                NULL|        1|            0|         32770|      NULL|     false|      NULL|        35104|1.641459543621913E9|            1.0|               0.0|            0.0|          0.0|                19.0|            312769.0|   536590.0|                2.0|                 0.0|       1040254.0|
# |        0|           68|     false|           0|                NULL|        1|            0|         47981|      NULL|     false|      NULL|        35104|1.641459544422786E9|            1.0|               0.0|            0.0|          0.0|                19.0|            337386.0|   824345.0|                2.0|                 0.0|       1040255.0|
# |        0|           28|     false|           0|                NULL|        1|            0|         16974|      NULL|     false|      NULL|        35105|1.641459544616979E9|            1.0|               0.0|            0.0|          0.0|                 5.0|            345358.0|  1875697.0|                2.0|                 0.0|       1040256.0|
# |        0|           28|     false|           0|                NULL|        1|            0|         20791|      NULL|     false|      NULL|        35104|1.641459545223427E9|            1.0|               0.0|            0.0|          0.0|                19.0|            331220.0|   533995.0|                2.0|                 0.0|       1040257.0|
# |        0|           28|     false|           0|                NULL|        1|            0|         16974|      NULL|     false|      NULL|        35106|1.641459545617399E9|            1.0|               0.0|            0.0|          0.0|                 5.0|            424091.0|  4739282.0|                2.0|                 0.0|       1318417.0|
# |        0|           28|     false|           0|                NULL|        1|            0|           192|      NULL|     false|      NULL|        35146|1.641459546023855E9|            1.0|               0.0|            0.0|          0.0|                19.0|            337891.0|  2596827.0|                2.0|                 0.0|       1040258.0|
# |        0|           28|     false|           0|                NULL|        1|            0|         24854|      NULL|     false|      NULL|        35104|1.641459546618036E9|            1.0|               0.0|            0.0|          0.0|                 5.0|            380570.0|   173649.0|                2.0|                 0.0|       1040259.0|
# +---------+-------------+----------+------------+--------------------+---------+-------------+--------------+----------+----------+----------+-------------+-------------------+---------------+------------------+---------------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+----------------+
# only showing top 20 rows

# %%
# Split the data into training and test sets
train_data, test_data = df_indexed.randomSplit([0.7, 0.3], seed=42)

# %%
from pyspark.ml.feature import Imputer

# List of numeric column names
numeric_columns = ['resp_pkts', 'orig_ip_bytes', 'missed_bytes', 'duration', 'orig_pkts',
                   'resp_ip_bytes', 'dest_port_zeek', 'orig_bytes', 'resp_bytes',
                   'src_port_zeek', 'ts']


# Create an Imputer object
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

# Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data)

# Apply the imputer to the training data
train_data_imputed = imputer_model.transform(train_data)

# Apply the imputer to the test data
test_data_imputed = imputer_model.transform(test_data)

# Show updated DataFrames
train_data_imputed.show()
test_data_imputed.show()
# Out:
# 24/04/07 01:21:05 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 01:22:01 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/04/07 01:22:14 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# +---------+-------------+----------+------------+--------+---------+-------------+--------------+----------+----------+----------+-------------+-------------------+---------------+------------------+---------------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+----------------+-----------------+---------------------+--------------------+------------------+-----------------+---------------------+----------------------+------------------+------------------+---------------------+-------------------+
# |resp_pkts|orig_ip_bytes|local_resp|missed_bytes|duration|orig_pkts|resp_ip_bytes|dest_port_zeek|orig_bytes|local_orig|resp_bytes|src_port_zeek|                 ts|service_indexed|conn_state_indexed|history_indexed|proto_indexed|dest_ip_zeek_indexed|community_id_indexed|uid_indexed|src_ip_zeek_indexed|label_tactic_indexed|datetime_indexed|resp_pkts_imputed|orig_ip_bytes_imputed|missed_bytes_imputed|  duration_imputed|orig_pkts_imputed|resp_ip_bytes_imputed|dest_port_zeek_imputed|orig_bytes_imputed|resp_bytes_imputed|src_port_zeek_imputed|         ts_imputed|
# +---------+-------------+----------+------------+--------+---------+-------------+--------------+----------+----------+----------+-------------+-------------------+---------------+------------------+---------------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+----------------+-----------------+---------------------+--------------------+------------------+-----------------+---------------------+----------------------+------------------+------------------+---------------------+-------------------+
# |        0|            0|     false|           0|    NULL|        0|            0|          4506|      NULL|     false|      NULL|        53494| 1.64158153959555E9|            1.0|               4.0|           75.0|          1.0|               316.0|            195876.0|  3790554.0|               43.0|                 0.0|       1072136.0|                0|                    0|                   0|1.9144812405017937|                0|                    0|                  4506|            200314|                69|                53494| 1.64158153959555E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             3|      NULL|     false|      NULL|        35105|1.641459159450322E9|            1.0|               0.0|            0.0|          0.0|                 5.0|            348355.0|  3983593.0|                2.0|                 0.0|         18144.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     3|            200314|                69|                35105|1.641459159450322E9|
# +---------+-------------+----------+------------+--------+---------+-------------+--------------+----------+----------+----------+-------------+-------------------+---------------+------------------+---------------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+----------------+-----------------+---------------------+--------------------+------------------+-----------------+---------------------+----------------------+------------------+------------------+---------------------+-------------------+
# only showing top 20 rows
# 24/04/07 01:22:42 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# [Stage 45:>                                                         (0 + 1) / 1]
# +---------+-------------+----------+------------+--------+---------+-------------+--------------+----------+----------+----------+-------------+-------------------+---------------+------------------+---------------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+----------------+-----------------+---------------------+--------------------+------------------+-----------------+---------------------+----------------------+------------------+------------------+---------------------+-------------------+
# |resp_pkts|orig_ip_bytes|local_resp|missed_bytes|duration|orig_pkts|resp_ip_bytes|dest_port_zeek|orig_bytes|local_orig|resp_bytes|src_port_zeek|                 ts|service_indexed|conn_state_indexed|history_indexed|proto_indexed|dest_ip_zeek_indexed|community_id_indexed|uid_indexed|src_ip_zeek_indexed|label_tactic_indexed|datetime_indexed|resp_pkts_imputed|orig_ip_bytes_imputed|missed_bytes_imputed|  duration_imputed|orig_pkts_imputed|resp_ip_bytes_imputed|dest_port_zeek_imputed|orig_bytes_imputed|resp_bytes_imputed|src_port_zeek_imputed|         ts_imputed|
# +---------+-------------+----------+------------+--------+---------+-------------+--------------+----------+----------+----------+-------------+-------------------+---------------+------------------+---------------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+----------------+-----------------+---------------------+--------------------+------------------+-----------------+---------------------+----------------------+------------------+------------------+---------------------+-------------------+
# |        0|            0|     false|           0|    NULL|        0|            0|         47761|      NULL|     false|      NULL|        51160|1.641581539831702E9|            1.0|               4.0|           88.0|          1.0|               316.0|            403481.0|  4485706.0|               43.0|                 0.0|        512219.0|                0|                    0|                   0|1.9144812405017937|                0|                    0|                 47761|            200314|                69|                51160|1.641581539831702E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             2|      NULL|     false|      NULL|        35104|1.641459223650203E9|            1.0|               0.0|            0.0|          0.0|                14.0|            316639.0|  4392359.0|                2.0|                 0.0|        574178.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     2|            200314|                69|                35104|1.641459223650203E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             2|      NULL|     false|      NULL|        35104|1.641459230052453E9|            1.0|               0.0|            0.0|          0.0|                16.0|            238360.0|  2707715.0|                2.0|                 0.0|       1039354.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     2|            200314|                69|                35104|1.641459230052453E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             2|      NULL|     false|      NULL|        35104|1.641459230052453E9|            1.0|               0.0|            0.0|          0.0|                16.0|            238360.0|  2707715.0|                2.0|                 0.0|       1039354.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     2|            200314|                69|                35104|1.641459230052453E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             3|      NULL|     false|      NULL|        35104|1.641459165253257E9|            1.0|               0.0|            0.0|          0.0|                17.0|            256239.0|  3381721.0|                2.0|                 0.0|         14086.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     3|            200314|                69|                35104|1.641459165253257E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             3|      NULL|     false|      NULL|        35104|1.641459551626413E9|            1.0|               0.0|            0.0|          0.0|                19.0|            411782.0|   816045.0|                2.0|                 0.0|       1040272.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     3|            200314|                69|                35104|1.641459551626413E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             3|      NULL|     false|      NULL|        35105|1.641459158545006E9|            1.0|               0.0|            0.0|          0.0|                14.0|            392616.0|  4438135.0|                2.0|                 0.0|        510563.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     3|            200314|                69|                35105|1.641459158545006E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             3|      NULL|     false|      NULL|        35105|1.641459159450322E9|            1.0|               0.0|            0.0|          0.0|                 5.0|            348355.0|  3983593.0|                2.0|                 0.0|         18144.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     3|            200314|                69|                35105|1.641459159450322E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             3|      NULL|     false|      NULL|        35105| 1.64145916535334E9|            1.0|               0.0|            0.0|          0.0|                17.0|            241240.0|  2748854.0|                2.0|                 0.0|         16264.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     3|            200314|                69|                35105| 1.64145916535334E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             3|      NULL|     false|      NULL|        35106|1.641459231260802E9|            1.0|               0.0|            0.0|          0.0|                 5.0|            272398.0|  2806839.0|                2.0|                 0.0|       1039361.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     3|            200314|                69|                35106|1.641459231260802E9|
# |        0|           28|     false|           0|    NULL|        1|            0|             9|      NULL|     false|      NULL|        35104|1.641459222255548E9|            1.0|               0.0|            0.0|          0.0|                14.0|            229650.0|  3793503.0|                2.0|                 0.0|        409890.0|                0|                   28|                   0|1.9144812405017937|                1|                    0|                     9|            200314|                69|                35104|1.641459222255548E9|
# +---------+-------------+----------+------------+--------+---------+-------------+--------------+----------+----------+----------+-------------+-------------------+---------------+------------------+---------------+-------------+--------------------+--------------------+-----------+-------------------+--------------------+----------------+-----------------+---------------------+--------------------+------------------+-----------------+---------------------+----------------------+------------------+------------------+---------------------+-------------------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import VectorAssembler

# List of columns to assemble
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed")]

# Create the VectorAssembler
assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

# Transform the training DataFrame
train_data_assembled = assembler.transform(train_data_imputed)

# Transform the test DataFrame
test_data_assembled = assembler.transform(test_data_imputed)

# Select only the features and label columns for both training and test sets
train_data_assembled = train_data_assembled.select("features", "label_tactic_indexed")
test_data_assembled = test_data_assembled.select("features", "label_tactic_indexed")

# Show the schema of the assembled training DataFrame
train_data_assembled.printSchema()

# Show the schema of the assembled test DataFrame
test_data_assembled.printSchema()
# Out:
# root
#  |-- features: vector (nullable = true)
#  |-- label_tactic_indexed: double (nullable = false)
#
# root
#  |-- features: vector (nullable = true)
#  |-- label_tactic_indexed: double (nullable = false)

# %%
"""
# Get the distinct values of the 'label_tactic_indexed' column
distinct_classes = train_data_assembled.select("label_tactic_indexed").distinct().collect()

# Convert the result to a list of unique classes
unique_classes = [row['label_tactic_indexed'] for row in distinct_classes]

# Print the unique classes
print("Unique classes:", unique_classes)

# Group by the 'label_tactic_indexed' column and count the occurrences of each class
class_counts = train_data_assembled.groupBy("label_tactic_indexed").count()

# Show the class counts
class_counts.show()

# Get the distinct values of the 'label_tactic_indexed' column
distinct_classes = test_data_assembled.select("label_tactic_indexed").distinct().collect()

# Convert the result to a list of unique classes
unique_classes = [row['label_tactic_indexed'] for row in distinct_classes]

# Print the unique classes
print("Unique classes:", unique_classes)

# Group by the 'label_tactic_indexed' column and count the occurrences of each class
class_counts = test_data_assembled.groupBy("label_tactic_indexed").count()

# Show the class counts
class_counts.show()
"""
# Out:
# '\n# Get the distinct values of the \'label_tactic_indexed\' column\ndistinct_classes = train_data_assembled.select("label_tactic_indexed").distinct().collect()\n\n# Convert the result to a list of unique classes\nunique_classes = [row[\'label_tactic_indexed\'] for row in distinct_classes]\n\n# Print the unique classes\nprint("Unique classes:", unique_classes)\n\n# Group by the \'label_tactic_indexed\' column and count the occurrences of each class\nclass_counts = train_data_assembled.groupBy("label_tactic_indexed").count()\n\n# Show the class counts\nclass_counts.show()\n\n# Get the distinct values of the \'label_tactic_indexed\' column\ndistinct_classes = test_data_assembled.select("label_tactic_indexed").distinct().collect()\n\n# Convert the result to a list of unique classes\nunique_classes = [row[\'label_tactic_indexed\'] for row in distinct_classes]\n\n# Print the unique classes\nprint("Unique classes:", unique_classes)\n\n# Group by the \'label_tactic_indexed\' column and count the occurrences of each class\nclass_counts = test_data_assembled.groupBy("label_tactic_indexed").count()\n\n# Show the class counts\nclass_counts.show()\n'

# %%
from pyspark.ml.feature import StandardScaler

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic_indexed")
# Out:
# 24/04/07 01:23:12 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 01:24:28 WARN DAGScheduler: Broadcasting large task binary with size 268.3 MiB

# %%
# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic_indexed")

# %%
# Define the PCA model
pca = PCA(k=5, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/04/07 01:24:55 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 01:25:27 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 01:25:54 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 01:27:03 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 01:27:25 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 01:27:53 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 01:28:08 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/04/07 01:28:58 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# Execution time: 271.0545392036438 seconds
# 24/04/07 01:29:03 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK

# %%
# Apply PCA transformation to the training and test sets
train_pca = pca_model.transform(train_data_normalized)
test_pca = pca_model.transform(test_data_normalized)

# %%
# Drop the normalized column and rename the pca_features column
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")

# Verify the changes
train_pca.show()
test_pca.show()
# Out:
# 24/04/07 01:29:16 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# +--------------------+--------------------+
# |label_tactic_indexed|            features|
# +--------------------+--------------------+
# |                 0.0|[0.00381634572699...|
# |                 0.0|[0.00364108990037...|
# |                 0.0|[0.00290472820931...|
# |                 0.0|[-0.0030413202161...|
# |                 0.0|[3.85918103803854...|
# |                 0.0|[3.85919609842803...|
# |                 0.0|[3.86197603010916...|
# |                 0.0|[3.86228771616004...|
# |                 0.0|[3.86228771616004...|
# |                 0.0|[3.86078110794005...|
# |                 0.0|[3.86078602694813...|
# |                 0.0|[3.86078602694813...|
# |                 0.0|[3.86356380420025...|
# |                 0.0|[3.86515157882944...|
# |                 0.0|[3.85916843321524...|
# |                 0.0|[3.85916843321524...|
# |                 0.0|[3.85918533502757...|
# |                 0.0|[3.86037296361757...|
# |                 0.0|[3.86075066270615...|
# |                 0.0|[3.86075344258596...|
# +--------------------+--------------------+
# only showing top 20 rows
# 24/04/07 01:29:42 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# [Stage 57:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+
# |label_tactic_indexed|            features|
# +--------------------+--------------------+
# |                 0.0|[0.00424598317500...|
# |                 0.0|[3.85918103803854...|
# |                 0.0|[3.85920069690697...|
# |                 0.0|[3.85920069690697...|
# |                 0.0|[3.86076604746783...|
# |                 0.0|[3.86076604746783...|
# |                 0.0|[3.86078110794005...|
# |                 0.0|[3.86356380420025...|
# |                 0.0|[3.86515157882944...|
# |                 0.0|[3.85916565323073...|
# |                 0.0|[3.85916565323073...|
# |                 0.0|[3.85918533502757...|
# |                 0.0|[3.85918655899770...|
# |                 0.0|[3.85918655899770...|
# |                 0.0|[3.86037296361757...|
# |                 0.0|[3.86075066270615...|
# |                 0.0|[3.86075344258596...|
# |                 0.0|[3.86077156850313...|
# |                 0.0|[3.86255864737474...|
# |                 0.0|[3.86047060555949...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
# Create the SVM model
#svm = LinearSVC(labelCol="label_tactic_indexed", featuresCol="features", maxIter=1)
#svm = LinearSVC(labelCol="label_tactic_indexed", featuresCol="features", predictionCol='prediction', maxIter=100, regParam=0.0, tol=.000001, fitIntercept=True, 
WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:25:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:26:04 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:26:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:26:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:26:56 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:27:13 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:27:31 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:27:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:28:04 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:28:22 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:28:39 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:28:56 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:29:14 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:29:31 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:29:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:30:06 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:30:23 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:30:40 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:30:58 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:31:16 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:31:33 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:31:50 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:32:06 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:32:25 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:32:42 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:32:59 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:33:16 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:33:33 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:33:50 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:34:07 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:34:24 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:34:41 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:34:58 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:35:15 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:35:30 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:35:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:36:06 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:36:23 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:36:40 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:36:57 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:37:13 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:37:32 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:37:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:38:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:38:24 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:38:40 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:38:56 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:39:13 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:39:30 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:39:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:40:02 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:40:22 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:40:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:40:54 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:41:10 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:41:27 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:41:44 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:42:01 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:42:17 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:42:37 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:42:54 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:43:11 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:43:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:43:44 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:44:00 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:44:17 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:44:34 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:44:50 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:45:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:45:24 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:45:40 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:45:57 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:46:12 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:46:32 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:46:50 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:47:08 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:47:23 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:47:43 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:47:59 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:48:16 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:48:33 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:48:50 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:49:07 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:49:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:49:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:50:03 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:50:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:50:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:50:54 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:51:15 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:51:20 ERROR OWLQN: Failure! Resetting history: breeze.optimize.NaNHistory:
# 24/04/07 02:51:33 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:51:51 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:52:07 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:52:26 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:52:43 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:53:01 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:53:18 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:53:36 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:53:53 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:54:11 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:54:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:54:45 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:55:03 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:55:20 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:55:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:55:55 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:56:12 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:56:29 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:56:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:57:04 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:57:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:57:38 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:57:56 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:58:13 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:58:30 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:58:48 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:59:05 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:59:23 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:59:41 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 02:59:58 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:00:15 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:00:33 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:00:49 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:01:09 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:01:26 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:01:46 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:02:03 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:02:21 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:02:37 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:02:55 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# Execution time: 5583.764046669006 seconds

# %%
# Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.30619096755981445 seconds

# %%
# Evaluate the model
# Calculate accuracy
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)

# Calculate precision
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)

# Calculate recall
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)

# Calculate F1-score
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic_indexed", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
# Out:
# 24/04/07 03:03:37 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:06:03 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:08:28 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# 24/04/07 03:10:54 WARN DAGScheduler: Broadcasting large task binary with size 268.4 MiB
# [Stage 380:=================================================>       (7 + 1) / 8]
# Accuracy: 0.9998498755727085
# Precision: 0.9997405328614634
# Recall: 0.9998498755727085
# F1-Score: 0.9997952010428275

# %%
spark.sparkContext.stop()
