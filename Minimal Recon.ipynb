# %%
import pyspark
from pyspark.sql import SparkSession

from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA, Imputer
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.sql.functions import mean, col, expr
import time

# %%
spark.sparkContext.stop()

# %%
spark = SparkSession.builder.appName("ce53") \
    .config("SPARK_LOCAL_IP", "192.168.1.2") \
    .master("spark://192.168.1.2:7077") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.memory", "10g") \
    .config("spark.executor.memory", "20g") \
    .config("spark.executor.cores", "16") \
    .config("spark.executor.instances", "6") \
    .config("spark.shuffle.partitions", "6") \
    .config("spark.kryoserializer.buffer.max", "256m") \
    .config("spark.sql.execution.pythonUDF.arrow.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# Warning: Ignoring non-Spark config property: SPARK_LOCAL_IP
# 24/05/12 17:57:29 WARN Utils: Your hostname, ubuntu-virtual-machine resolves to a loopback address: 127.0.1.1; using 192.168.1.106 instead (on interface ens33)
# 24/05/12 17:57:29 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/12 17:57:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
parquet_files = ["hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2021-12-12 - 2021-12-19/part-00000-7c2e9adb-5430-4792-a42b-10ff5bbd46e8-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2021-12-19 - 2021-12-26/part-00000-3f86626a-1225-47f9-a5a2-0170b737e404-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2021-12-26 - 2022-01-02/part-00000-b1a9fc13-8068-4a5d-91b2-871438709e81-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-01-02 - 2022-01-09/part-00000-26e9208e-7819-451b-b23f-2e47f6d1e834-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-01-09 - 2022-01-16/part-00000-36240b61-b84f-4164-a873-d7973e652780-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-01-16 - 2022-01-23/part-00000-cbf26680-106d-40e7-8278-60520afdbb0e-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-02-06 - 2022-02-13/part-00000-df678a79-4a73-452b-8e72-d624b2732f17-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekData22/parquet/2022-02-13 - 2022-02-20/part-00000-1da06990-329c-4e38-913a-0f0aa39b388d-c000.snappy.parquet"]

# %%
#Read the parquet files
df = spark.read.parquet(*parquet_files, inferSchema=True)

# %%
#Get unique label counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

label_counts.show()
# Out:
# +--------------------+-------+
# |        label_tactic|  count|
# +--------------------+-------+
# |   Credential Access|     31|
# |     Defense Evasion|      1|
# |           Discovery|   2086|
# |        Exfiltration|      7|
# |      Initial Access|      1|
# |    Lateral Movement|      4|
# |         Persistence|      1|
# |Privilege Escalation|     13|
# |      Reconnaissance|9278722|
# |Resource Development|      3|
# |                none|9281599|
# +--------------------+-------+

# %%
start_time = time.time()

#Drop labels and get remaining counts
labels_to_drop = ['Defense Evasion', 
                  'Exfiltration',
                  'Initial Access',
                  'Lateral Movement', 
                  'Persistence',
                  'Privilege Escalation', 
                  'Resource Development', 
                  'Credential Access', 
                  'Discovery']

df = df.filter(~col("label_tactic").isin(labels_to_drop))
filtered_label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

filtered_label_counts.show()

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# [Stage 4:========================================================>(93 + 1) / 94]
# +--------------+-------+
# |  label_tactic|  count|
# +--------------+-------+
# |Reconnaissance|9278722|
# |          none|9281599|
# +--------------+-------+
#
# Execution time: 2.3246207237243652 seconds

# %%
start_time = time.time()

#Drop uid feature
df = df.drop('uid')

#Columns to index
columns_to_index = ['service', 
                    'conn_state', 
                    'history', 
                    'proto', 
                    'dest_ip_zeek', 
                    'community_id', 
                    'src_ip_zeek',
                    'datetime',
                    'local_resp',
                    'local_orig',
                    'label_tactic']

#Cast datetime, local_resp, local_orig to String
df = df.withColumn("datetime", col("datetime").cast("string"))
df = df.withColumn("local_resp", col("local_resp").cast("string"))
df = df.withColumn("local_orig", col("local_orig").cast("string"))

#Impute null values with empty string
for column in columns_to_index:
    df = df.fillna('', subset=[column])

#StringIndexer
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").fit(df) for column in columns_to_index]

#Chain indexers together
pipeline = Pipeline(stages=indexers)

#Fit and transform the data
df_indexed = pipeline.fit(df).transform(df)

#Drop original columns
df_indexed = df_indexed.drop(*columns_to_index)
df_indexed = df_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")

#df_indexed.show(5)

print("df_indexed columns: ", df_indexed.columns)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# df_indexed columns:  ['resp_pkts', 'orig_ip_bytes', 'missed_bytes', 'duration', 'orig_pkts', 'resp_ip_bytes', 'dest_port_zeek', 'orig_bytes', 'resp_bytes', 'src_port_zeek', 'ts', 'service_indexed', 'conn_state_indexed', 'history_indexed', 'proto_indexed', 'dest_ip_zeek_indexed', 'community_id_indexed', 'src_ip_zeek_indexed', 'datetime_indexed', 'local_resp_indexed', 'local_orig_indexed', 'label_tactic']
# Execution time: 62.81421113014221 seconds

# %%
#Split the into training and test sets
start_time = time.time()
train_data, test_data = df_indexed.randomSplit([0.7, 0.3], seed=42)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.07378721237182617 seconds

# %%
start_time = time.time()

#List of numeric column names
numeric_columns = ['resp_pkts', 
                   'orig_ip_bytes', 
                   'missed_bytes', 
                   'duration', 
                   'orig_pkts',
                   'resp_ip_bytes', 
                   'dest_port_zeek', 
                   'orig_bytes', 
                   'resp_bytes',
                   'src_port_zeek', 
                   'ts']

#Create Imputer
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

#Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data)

#Apply the Imputer to the training data
train_data_imputed = imputer_model.transform(train_data)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Apply the Imputer to the test data
start_time = time.time()
test_data_imputed = imputer_model.transform(test_data)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

train_data_imputed = train_data_imputed.drop(*numeric_columns)
test_data_imputed = test_data_imputed.drop(*numeric_columns)

print("\nTrain data imputed: ", train_data_imputed.columns)
print("\n")
print("Test data imputed: ", test_data_imputed.columns)
# Out:
# 24/05/12 17:58:56 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# Execution time: 37.927582025527954 seconds
# Execution time: 0.022930622100830078 seconds
#
# Train data imputed:  ['service_indexed', 'conn_state_indexed', 'history_indexed', 'proto_indexed', 'dest_ip_zeek_indexed', 'community_id_indexed', 'src_ip_zeek_indexed', 'datetime_indexed', 'local_resp_indexed', 'local_orig_indexed', 'label_tactic', 'resp_pkts_imputed', 'orig_ip_bytes_imputed', 'missed_bytes_imputed', 'duration_imputed', 'orig_pkts_imputed', 'resp_ip_bytes_imputed', 'dest_port_zeek_imputed', 'orig_bytes_imputed', 'resp_bytes_imputed', 'src_port_zeek_imputed', 'ts_imputed']
#
#
# Test data imputed:  ['service_indexed', 'conn_state_indexed', 'history_indexed', 'proto_indexed', 'dest_ip_zeek_indexed', 'community_id_indexed', 'src_ip_zeek_indexed', 'datetime_indexed', 'local_resp_indexed', 'local_orig_indexed', 'label_tactic', 'resp_pkts_imputed', 'orig_ip_bytes_imputed', 'missed_bytes_imputed', 'duration_imputed', 'orig_pkts_imputed', 'resp_ip_bytes_imputed', 'dest_port_zeek_imputed', 'orig_bytes_imputed', 'resp_bytes_imputed', 'src_port_zeek_imputed', 'ts_imputed']

# %%
start_time = time.time()

#Create VectorAssembler
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed") or column.endswith("_indexed")]
print("Columns to assemble: ", columns_to_assemble)

assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

#Transform the training data
train_data_assembled = assembler.transform(train_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Transform the test data
start_time = time.time()
test_data_assembled = assembler.transform(test_data_imputed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Select the features and label columns
train_data_assembled = train_data_assembled.select("features", "label_tactic")
test_data_assembled = test_data_assembled.select("features", "label_tactic")

print("Train_data_assembled columns: ", train_data_assembled.columns)
print("Test_data_assembled columns: ", test_data_assembled.columns)

#filtered_label_counts = train_data_assembled.groupBy("label_tactic").count()
#filtered_label_counts.show()
#filtered_label_counts = train_data_assembled.groupBy("features").count()
#filtered_label_counts.limit(20).show()
# Out:
# Columns to assemble:  ['service_indexed', 'conn_state_indexed', 'history_indexed', 'proto_indexed', 'dest_ip_zeek_indexed', 'community_id_indexed', 'src_ip_zeek_indexed', 'datetime_indexed', 'local_resp_indexed', 'local_orig_indexed', 'resp_pkts_imputed', 'orig_ip_bytes_imputed', 'missed_bytes_imputed', 'duration_imputed', 'orig_pkts_imputed', 'resp_ip_bytes_imputed', 'dest_port_zeek_imputed', 'orig_bytes_imputed', 'resp_bytes_imputed', 'src_port_zeek_imputed', 'ts_imputed']
# Execution time: 2.211923360824585 seconds
# Execution time: 2.128499984741211 seconds
# Train_data_assembled columns:  ['features', 'label_tactic']
# Test_data_assembled columns:  ['features', 'label_tactic']

# %%
#Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)
ovr = OneVsRest(classifier=svm, labelCol="label_tactic")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Fit the model
start_time = time.time()
svm_model = ovr.fit(train_data_assembled)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.2672407627105713 seconds
# 24/05/12 17:59:49 WARN DAGScheduler: Broadcasting large task binary with size 80.8 MiB
# 24/05/12 18:00:20 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/05/12 18:00:26 WARN DAGScheduler: Broadcasting large task binary with size 80.8 MiB
# 24/05/12 18:01:12 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:01:27 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:01:35 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:01:54 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:00 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:06 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:11 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:17 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:23 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:28 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:34 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:39 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:45 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:50 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:02:56 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:01 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:07 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:12 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:17 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:22 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:28 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:32 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:38 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:43 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:49 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:03:54 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:00 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:05 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:11 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:16 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:21 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:26 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:32 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:37 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:43 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:48 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:53 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:04:58 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:04 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:09 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:15 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:20 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:25 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:31 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:36 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:41 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:47 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:52 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:05:58 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:06:03 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:06:09 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:06:14 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:06:19 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:06:24 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:06:30 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:06:45 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:06:50 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:09 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:15 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:20 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:26 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:31 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:36 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:41 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:46 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:51 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:07:57 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:03 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:08 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:13 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:19 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:24 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:29 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:35 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:40 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:45 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:51 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:08:56 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:02 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:08 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:13 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:19 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:24 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:29 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:35 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:40 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:45 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:50 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:09:55 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:01 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:06 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:11 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:16 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:21 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:27 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:32 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:37 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:42 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:48 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:53 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:10:58 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:11:03 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:11:08 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:11:14 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:11:19 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:11:24 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:11:30 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:11:35 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# Execution time: 713.572361946106 seconds

# %%
#Make predictions
start_time = time.time()

predictions = svm_model.transform(test_data_assembled)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 1.174107551574707 seconds

# %%
#Calculate accuracy
start_time = time.time()
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Calculate precision
start_time = time.time()
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Calculate recall
start_time = time.time()
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Calculate F1-score
#start_time = time.time()
#evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="f1")
#f1_score = evaluator_f1.evaluate(predictions)
#end_time = time.time()
#execution_time = end_time - start_time
#print("Execution time:", execution_time, "seconds")

#Print results
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
#print("F1-Score:", f1_score)
# Out:
# 24/05/12 18:11:57 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# Execution time: 97.66669845581055 seconds
# 24/05/12 18:13:32 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# Execution time: 90.77669048309326 seconds
# 24/05/12 18:15:01 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# [Stage 163:======================================================>(93 + 1) / 94]
# Execution time: 96.932621717453 seconds
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0

# %%
start_time = time.time()

#Extract predictions and labels
predictions_and_labels = predictions.select("prediction", "label_tactic")

#Calculate false positives and true negatives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic== 0)).count()
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic == 0)).count()

#Calculate FPR
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/05/12 18:17:06 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# 24/05/12 18:17:59 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# [Stage 168:======================================================>(93 + 1) / 94]
# False Positive Rate: 0.0
# Execution time: 100.26958894729614 seconds

# %%
#Calculate F1-score
start_time = time.time()
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
print("F1-Score:", f1_score)
# Out:
# 24/05/12 18:19:08 WARN DAGScheduler: Broadcasting large task binary with size 80.9 MiB
# [Stage 171:======================================================>(93 + 1) / 94]
# Execution time: 88.68814325332642 seconds
# F1-Score: 1.0

# %%
spark.sparkContext.stop()
