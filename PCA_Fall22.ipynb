# %%
import pyspark
from pyspark.sql import SparkSession

from pyspark.ml.classification import LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import VectorAssembler, StringIndexer, PCA, Imputer
from pyspark.ml.classification import OneVsRest
from pyspark.ml import Pipeline
from pyspark.sql.functions import mean, col, expr
import numpy as np
import time

# %%
spark = SparkSession.builder.appName("rka7 - PCA Multi") \
    .config("SPARK_LOCAL_IP", "192.168.1.2") \
    .master("spark://192.168.1.2:7077") \
    .config("spark.driver.cores", "2") \
    .config("spark.driver.maxResultSize", "3g") \
    .config("spark.driver.memory", "10g") \
    .config("spark.executor.memory", "25g") \
    .config("spark.executor.cores", "2") \
    .config("spark.executor.instances", "16") \
    .config("spark.shuffle.partitions", "180") \
    .config("spark.kryoserializer.buffer.max", "256m") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "false") \
    .config("spark.executor.heartbeatInterval","11999s") \
    .config("spark.sql.execution.arrow.enabled", "true") \
    .config("spark.network.timeout","12000s") \
.getOrCreate()
# Out:
# Warning: Ignoring non-Spark config property: SPARK_LOCAL_IP
# 24/06/11 02:07:47 WARN Utils: Your hostname, ubuntu-virtual-machine resolves to a loopback address: 127.0.1.1; using 192.168.1.107 instead (on interface ens33)
# 24/06/11 02:07:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/06/11 02:07:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#spark.sparkContext.stop()

# %%
parquet_files = ["hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-12 - 2021-12-19/part-00000-d512890f-d1e9-49d5-a136-f87f0183cb4d-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-19 - 2021-12-26/part-00000-d28b031b-bff1-4e16-853a-9b7d896627e7-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2021-12-26 - 2022-01-02/part-00000-94d13437-ae00-4a8c-9f38-edd0196cfdee-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-01-02 - 2022-01-09/part-00000-745e350a-da9e-4619-bd52-8cc23bb41ad5-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-08-28 - 2022-09-04/part-00000-9a46dd05-4b06-4a39-a45b-5c8460b6c37b-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-04 - 2022-09-11/part-00000-ea53b0e8-d346-44e3-9a87-1f60ac35c610-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-11 - 2022-09-18/part-00000-f9afaec0-242e-41e7-906d-a42681515d75-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-18 - 2022-09-25/part-00000-9ac876be-c07d-4a18-878d-959efa26f484-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-09-25 - 2022-10-02/part-00000-be6d0798-554d-4c7a-9fef-d4c07aa0ce19-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-02 - 2022-10-09/part-00000-2b76f9cc-0710-45e4-9e33-98ad5808ee79-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-09 - 2022-10-16/part-00000-b2b625bc-5816-4586-b977-35f9ed4487fd-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-16 - 2022-10-23/part-00000-9aeb279c-81c6-4481-9b30-d35d4d194fea-c000.snappy.parquet",
                 "hdfs://192.168.1.2:9000/datasets-uwf-edu/UWF-ZeekDataFall22/parquet/2022-10-23 - 2022-10-30/part-00000-23fdcfa3-9dd3-4c72-886c-e945bfcf92e1-c000.snappy.parquet"]

# %%
#Read the parquet files
df = spark.read.parquet(*parquet_files, inferSchema=True)
# Out:
# 24/06/11 02:07:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/06/11 02:07:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/06/11 02:07:49 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.

# %%
#Get unique label counts
label_counts = df.groupBy("label_tactic").count().orderBy("label_tactic")

label_counts.show()
# Out:
# +--------------------+------+
# |        label_tactic| count|
# +--------------------+------+
# |          Collection|     1|
# | Command and Control|    17|
# |   Credential Access|     1|
# |     Defense Evasion|  3064|
# |           Discovery| 16819|
# |           Execution|    30|
# |      Initial Access|    19|
# |    Lateral Movement|    11|
# |         Persistence|    10|
# |Privilege Escalation|  3066|
# |      Reconnaissance| 51492|
# |Resource Development|275471|
# |                none|350339|
# +--------------------+------+

# %%
start_time = time.time()

#Drop labels and get remaining counts
labels_to_drop = ['Defense Evasion', 
                  'Exfiltration',
                  'Initial Access',
                  'Lateral Movement', 
                  'Persistence',
                  'Privilege Escalation', 
                  'Resource Development', 
                  'Credential Access']
                  #'Discovery',
                  #'Reconnaissance']

df = df.filter(~col("label_tactic").isin(labels_to_drop))

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.04125833511352539 seconds

# %%
#Drop uid feature
df = df.drop('uid')

# %%
start_time = time.time()

#Columns to index
columns_to_index = ['service', 
                    'conn_state', 
                    'history', 
                    'proto', 
                    'dest_ip_zeek', 
                    'community_id', 
                    'src_ip_zeek',
                    'datetime',
                    'local_resp',
                    'local_orig',
                    'label_tactic']

#Cast datetime, local_resp, local_orig to String
df = df.withColumn("datetime", col("datetime").cast("string"))
df = df.withColumn("local_resp", col("local_resp").cast("string"))
df = df.withColumn("local_orig", col("local_orig").cast("string"))

#Impute null values with empty string
for column in columns_to_index:
    df = df.fillna('', subset=[column])

# %%
#Split the into training and test sets
start_time = time.time()
train_data, test_data = df.randomSplit([0.7, 0.3], seed=42)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.030261754989624023 seconds

# %%
#StringIndexer
indexers = [StringIndexer(inputCol=column, outputCol=column+"_indexed").setHandleInvalid("keep") for column in columns_to_index]

#Chain indexers together
pipeline = Pipeline(stages=indexers).fit(train_data)

#Fit and transform the data
train_data_indexed = pipeline.transform(train_data)
test_data_indexed = pipeline.transform(test_data)

#Drop original columns
train_data_indexed = train_data_indexed.drop(*columns_to_index)
train_data_indexed = train_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")
test_data_indexed = test_data_indexed.drop(*columns_to_index)
test_data_indexed = test_data_indexed.withColumnRenamed("label_tactic_indexed", "label_tactic")

#print("train_indexed columns: ", train_data_indexed.columns)
#print("test_indexed columns: ", test_data_indexed.columns)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 38.3182852268219 seconds

# %%
start_time = time.time()

#List of numeric column names
numeric_columns = ['resp_pkts', 
                   'orig_ip_bytes', 
                   'missed_bytes', 
                   'duration', 
                   'orig_pkts',
                   'resp_ip_bytes', 
                   'dest_port_zeek', 
                   'orig_bytes', 
                   'resp_bytes',
                   'src_port_zeek', 
                   'ts']

#Create Imputer
imputer = Imputer(
    inputCols=numeric_columns,
    outputCols=["{}_imputed".format(column) for column in numeric_columns]
)

#Fit the imputer to the training data
imputer_model = imputer.setStrategy("mean").fit(train_data_indexed)

#Apply the Imputer to the training data
train_data_imputed = imputer_model.transform(train_data_indexed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Apply the Imputer to the test data
start_time = time.time()
test_data_imputed = imputer_model.transform(test_data_indexed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

train_data_imputed = train_data_imputed.drop(*numeric_columns)
test_data_imputed = test_data_imputed.drop(*numeric_columns)

#print("\nTrain data imputed: ", train_data_imputed.columns)
#print("\n")
#print("Test data imputed: ", test_data_imputed.columns)
# Out:
# Execution time: 2.951770305633545 seconds
# Execution time: 0.023934602737426758 seconds

# %%
start_time = time.time()

#Create VectorAssembler
columns_to_assemble = [column for column in train_data_imputed.columns if column.endswith("_imputed") or column.endswith("_indexed")]
#print("Columns to assemble: ", columns_to_assemble)

assembler = VectorAssembler(inputCols=columns_to_assemble, outputCol="features")

#Transform the training data
train_data_assembled = assembler.transform(train_data_imputed)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Transform the test data
start_time = time.time()
test_data_assembled = assembler.transform(test_data_imputed)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")

#Select the features and label columns
train_data_assembled = train_data_assembled.select("features", "label_tactic")
test_data_assembled = test_data_assembled.select("features", "label_tactic")

#print("Train_data_assembled columns: ", train_data_assembled.columns)
#print("Test_data_assembled columns: ", test_data_assembled.columns)
# Out:
# Execution time: 0.8822853565216064 seconds
# Execution time: 0.27405738830566406 seconds

# %%
from pyspark.ml.feature import StandardScaler

# Standardize data on the training set
scaler = StandardScaler(inputCol="features", outputCol="features_normalized", withMean=True, withStd=True)
scaler_model = scaler.fit(train_data_assembled)
train_data_normalized = scaler_model.transform(train_data_assembled)
train_data_normalized = train_data_normalized.select("features_normalized", "label_tactic")
# Out:
# 24/06/11 02:08:45 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/06/11 02:08:46 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB
# 24/06/11 02:08:49 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB

# %%
# Apply the same transformation to the test set
test_data_normalized = scaler_model.transform(test_data_assembled)
test_data_normalized = test_data_normalized.select("features_normalized", "label_tactic")

# %%
# Define the PCA model
pca = PCA(k=11, inputCol="features_normalized", outputCol="pca_features")

# Fit the PCA model on the normalized training set
start_time = time.time()
pca_model = pca.fit(train_data_normalized)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/06/11 02:08:52 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB
# 24/06/11 02:08:55 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB
# 24/06/11 02:08:57 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB
# 24/06/11 02:09:00 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB
# 24/06/11 02:09:03 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB
# 24/06/11 02:09:05 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB
# 24/06/11 02:09:09 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB
# [Stage 53:>                                                         (0 + 4) / 4]
# Execution time: 21.036040782928467 seconds

# %%
# Apply PCA transformation to the training and test sets
train_pca = pca_model.transform(train_data_normalized)
test_pca = pca_model.transform(test_data_normalized)

# %%
# Drop the normalized column and rename the pca_features column
train_pca = train_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")
test_pca = test_pca.drop("features_normalized").withColumnRenamed("pca_features", "features")

# Verify the changes
#train_pca.show()
#test_pca.show()

# %%
#Create the SVM model
start_time = time.time()
svm = LinearSVC(labelCol="label_tactic", featuresCol="features", maxIter=10, regParam=0.0, tol=.00001, fitIntercept=True)
ovr = OneVsRest(classifier=svm, labelCol="label_tactic")
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 0.029637813568115234 seconds

# %%
#Fit the model
start_time = time.time()
svm_model = ovr.fit(train_pca)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/06/11 02:09:13 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# 24/06/11 02:09:14 WARN DAGScheduler: Broadcasting large task binary with size 21.0 MiB
# 24/06/11 02:09:18 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:21 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:23 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:25 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:28 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:32 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:33 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:35 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:37 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:39 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:40 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:44 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:47 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:48 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:52 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:54 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:55 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:56 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:57 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:58 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:09:59 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:01 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:02 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:03 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:04 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:06 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:08 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:09 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:11 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:12 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:13 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:14 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:16 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:18 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:21 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:23 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:26 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:30 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:32 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:34 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:35 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:37 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:38 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:39 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:42 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:44 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:47 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:48 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:49 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:53 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:54 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:55 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:56 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:57 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:10:59 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:00 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:01 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:02 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:03 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:04 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:05 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:08 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:09 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:10 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:12 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:13 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:14 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:15 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:18 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:19 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:25 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:26 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:28 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:32 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:33 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:34 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:37 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:38 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:39 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:42 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:44 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:47 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:48 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:49 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:53 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:54 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:55 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:56 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:57 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:11:58 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:00 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:01 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:02 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:03 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:05 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:06 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:08 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:09 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:10 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:12 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:13 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:14 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:15 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:16 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:18 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:21 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:23 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:26 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:28 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:32 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:33 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:34 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:37 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:38 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:39 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:40 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:44 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:45 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:48 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:49 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:53 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:54 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:55 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:56 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:57 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:12:58 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:00 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:01 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:02 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:03 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:04 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:05 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:08 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:09 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:10 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:12 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:13 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:14 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:15 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:16 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:19 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:21 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:25 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:26 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:28 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:32 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:33 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:34 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:37 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:38 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:39 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:42 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:44 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:45 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:47 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:49 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:52 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:53 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:55 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:56 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:57 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:58 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:13:59 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:00 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:02 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:03 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:04 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:06 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:08 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:09 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:10 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:12 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:13 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:14 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:15 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:16 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:19 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:21 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:23 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:26 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:28 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:30 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:33 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:33 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:35 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:37 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:38 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:40 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:42 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:45 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:47 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:48 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:52 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:53 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:54 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:55 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:56 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:57 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:58 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:14:59 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:01 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:02 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:03 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:04 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:06 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:08 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:09 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:10 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:11 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:12 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:13 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:15 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:16 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:18 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:19 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:23 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:25 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:30 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:32 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:34 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:34 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:37 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:38 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:39 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:40 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:44 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:45 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:47 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:48 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:52 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:53 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:55 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:56 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:57 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:15:58 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:00 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:01 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:02 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:03 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:04 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:05 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:09 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:10 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:11 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:12 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:13 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:15 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:16 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:19 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:21 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:23 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:26 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:28 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:32 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:33 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:34 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:35 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:38 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:39 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:40 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:42 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:45 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:47 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:48 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:52 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:53 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:55 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:56 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:57 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:58 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:16:59 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:00 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:02 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:03 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:04 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:05 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:08 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:09 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:10 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:12 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:13 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:14 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:15 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:16 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:19 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:21 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:23 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:26 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:27 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:28 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:30 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:33 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:34 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:35 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:37 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:38 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:40 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:42 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:44 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:45 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:47 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:48 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:49 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:50 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:52 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:54 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:55 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:56 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:57 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:58 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:17:59 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:01 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:02 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:03 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:04 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:06 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:07 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:08 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:09 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:10 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:11 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:13 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:14 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:15 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:16 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:18 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:20 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:21 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:22 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:23 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:24 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:25 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:26 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:28 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:29 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:30 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:32 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:33 ERROR OWLQN: Failure! Resetting history: breeze.optimize.NaNHistory:
# 24/06/11 02:18:34 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:35 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:36 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:37 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:38 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:39 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:41 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:42 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:43 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:44 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:47 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:48 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:49 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:52 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:53 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:18:54 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# Execution time: 583.3395936489105 seconds

# %%
#Make predictions
start_time = time.time()

predictions = svm_model.transform(test_pca)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/06/11 02:18:55 WARN SQLConf: The SQL config 'spark.sql.execution.arrow.enabled' has been deprecated in Spark v3.0 and may be removed in the future. Use 'spark.sql.execution.arrow.pyspark.enabled' instead of it.
# Execution time: 0.7815465927124023 seconds

# %%
# Evaluate the model
# Calculate accuracy
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="accuracy")
accuracy = evaluator_accuracy.evaluate(predictions)

# Calculate precision
evaluator_precision = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedPrecision")
precision = evaluator_precision.evaluate(predictions)

# Calculate recall
evaluator_recall = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedRecall")
recall = evaluator_recall.evaluate(predictions)

# Calculate F1-score
evaluator_f1 = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="f1")
f1_score = evaluator_f1.evaluate(predictions)

#Calculate FPR
evaluator_fprL = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="falsePositiveRateByLabel")
fprL_score = evaluator_fprL.evaluate(predictions)

#Calculate Weighted FPR
evaluator_fpr = MulticlassClassificationEvaluator(labelCol="label_tactic", metricName="weightedFalsePositiveRate")
fpr_score = evaluator_fpr.evaluate(predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1_score)
print("FPR by Label:", fprL_score)
print("Weighted FPR:", fpr_score)
# Out:
# 24/06/11 02:18:59 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:19:08 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:19:17 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:19:25 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:19:31 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:19:39 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# [Stage 548:====================================================>  (20 + 1) / 21]
# Accuracy: 0.9791684950414475
# Precision: 0.9856136945666111
# Recall: 0.9791684950414475
# F1-Score: 0.9801472359494853
# FPR by Label: 0.004802273729602588
# Weighted FPR: 0.004870190190198972

# %%
start_time = time.time()

#Extract predictions and labels
predictions_and_labels = predictions.select("prediction", "label_tactic")

#Calculate false positives and true negatives
false_positives = predictions_and_labels.filter((predictions_and_labels.prediction == 1) & (predictions_and_labels.label_tactic== 0)).count()
true_negatives = predictions_and_labels.filter((predictions_and_labels.prediction == 0) & (predictions_and_labels.label_tactic == 0)).count()

#Calculate FPR
fpr = false_positives / (false_positives + true_negatives)

print("False Positive Rate:", fpr)
end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time, "seconds")
# Out:
# 24/06/11 02:19:46 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:19:51 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# [Stage 553:====================================================>  (20 + 1) / 21]
# False Positive Rate: 9.531888934430135e-06
# Execution time: 12.115039348602295 seconds

# %%
from pyspark.mllib.evaluation import BinaryClassificationMetrics
from pyspark.sql import Row

# Convert DataFrame to RDD of tuples (prediction, label)
prediction_and_labels = predictions.select("prediction", "label_tactic") \
    .rdd.map(lambda row: (float(row['prediction']), float(row['label_tactic'])))


# Instantiate BinaryClassificationMetrics
metrics = BinaryClassificationMetrics(prediction_and_labels)

# Compute AUROC
auROC = metrics.areaUnderROC

# Print AUROC
print("Area under ROC = ", auROC)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/pyspark/sql/context.py:158: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# 24/06/11 02:19:58 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# 24/06/11 02:20:00 WARN DAGScheduler: Broadcasting large task binary with size 21.1 MiB
# Area under ROC =  0.9974333358076011

# %%
spark.sparkContext.stop()
